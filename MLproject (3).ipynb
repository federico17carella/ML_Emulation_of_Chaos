# %% [markdown]
# # Dataset

# %%
import os
import sys
import random
import warnings

# 1.1 Suppress System Verbosity & Warnings Before Compiling
warnings.filterwarnings('ignore', category=UserWarning, module='backend_interactivity')
warnings.filterwarnings('ignore', message='.*Type-based sharding.*')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'          # Suppress core TensorFlow INFO/WARN logs
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'  # Dynamically allocate GPU memory footprint

# 1.2 Establish Strict Reproducibility Seeds
SEED = 17
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)

# 1.3 Core Mathematical & Scientific Stack
import numpy as np
from scipy.integrate import solve_ivp
from numpy.lib.stride_tricks import sliding_window_view

np.random.seed(SEED)

# 1.4 Graphics & Visualization Configurations
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.mplot3d import Axes3D

# Smart Backend Handling: Fall back to headless 'Agg' only if no display server exists
if 'IPython' in sys.modules:
    # If running in a Jupyter Notebook, allow standard inline plotting
    mpl.use('module://matplotlib_inline.backend_inline')
elif os.environ.get('DISPLAY') is None and not os.environ.get('WAYLAND_DISPLAY'):
    # Headless server fallback (prevents crash on remote SSH clusters without X11)
    mpl.use('Agg')

# 1.5 Deep Learning Framework (PyTorch version)
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torchsummary import summary

SEED = 42

# Set global seeds
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# Enable deterministic behavior
torch.use_deterministic_algorithms(False)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Running on:", device)


# =============================================================================
# 📊 SYSTEM DIAGNOSTICS & VERIFICATION
# =============================================================================

print("--------------------------------------------------")
print(f"📦 Environment Verification Successful")
print("--------------------------------------------------")
print(f"Python Version : {sys.version.split()[0]}")
print(f"NumPy Version  : {np.__version__}")
print(f"PyTorch Version: {torch.__version__}")
print(f"Matplotlib     : {mpl.__version__} [Backend: {mpl.get_backend()}]")
print("--------------------------------------------------")

# Query Available Compute Hardware
num_cpus = torch.get_num_threads()
gpu_available = torch.cuda.is_available()
num_gpus = torch.cuda.device_count()

print(f"🖥️ Execution Hardware:")
print(f"   • CPUs Detected: {num_cpus}")
if gpu_available:
    print(f"   • GPUs Detected: {num_gpus} [{torch.cuda.get_device_name(0)}]")
else:
    print("   • GPUs Detected: 0 [Running on CPU Baseline]")
print("--------------------------------------------------")
print("✓ Environment locked. Ready for data ingestion.")
# Out:
# Running on: cuda
# --------------------------------------------------
# 📦 Environment Verification Successful
# --------------------------------------------------
# Python Version : 3.9.13
# NumPy Version  : 2.0.2
# PyTorch Version: 2.7.1+cu118
# Matplotlib     : 3.9.4 [Backend: module://matplotlib_inline.backend_inline]
# --------------------------------------------------
# 🖥️ Execution Hardware:
#    • CPUs Detected: 36
#    • GPUs Detected: 1 [NVIDIA A100-PCIE-40GB]
# --------------------------------------------------
# ✓ Environment locked. Ready for data ingestion.

# %%
def lorenz96_rhs_vec(t, state, F=8.0):
    """
    Vectorized Right-Hand Side (RHS) of the Lorenz 96 system.
    Exploits np.roll to efficiently evaluate periodic boundary conditions.
    
    Equations handled simultaneously:
        dx_i/dt = (x_{i+1} - x_{i-2}) * x_{i-1} - x_i + F
    """
    # np.roll shifts elements along the axis. 
    # Shift -1 brings x_{i+1} to position i. Shift 2 brings x_{i-2} to position i.
    return (np.roll(state, -1) - np.roll(state, 2)) * np.roll(state, 1) - state + F


def integrate_lorenz96(state0, t_span, dt_eval, F=8.0):
    """
    Integrates the high-dimensional Lorenz 96 system using an explicit
    Adaptive Runge-Kutta method (RK45 via Scipy solve_ivp).
    
    Parameters:
        state0 (ndarray): Initial conditions vector of shape (N,).
        t_span (tuple): (t_start, t_end) integration window.
        dt_eval (float): The temporal sampling resolution for the ML data grid.
    """
    t_eval = np.arange(t_span[0], t_span[1], dt_eval)
    sol = solve_ivp(
        fun=lorenz96_rhs_vec, 
        t_span=t_span, 
        y0=state0,
        method='RK45', 
        t_eval=t_eval,
        args=(F,), 
        rtol=1e-8, 
        atol=1e-10  # Standard tolerances for high-dimensional chaotic tracking
    )
    return sol.t, sol.y.T


# -----------------------------------------------------------------------------
# ⚙️ Configuration & Boundary Init Setup
# -----------------------------------------------------------------------------
L96_N       = 40     # Dimension of the latitude circle grid
L96_F       = 8.0    # Forcing amplitude parameter (Fully chaotic regime)
L96_DT_ML   = 0.05   # Target downsampled sampling interval for ML windows

print(f"⏳ Initializing Lorenz 96 Data Generation (Grid Points N = {L96_N})...")

# Construct the initial unstable equilibrium state 
# We seed a tiny 0.01 perturbation at the center grid point to trigger wave growth
state0_96 = np.ones(L96_N) * L96_F
state0_96[L96_N // 2] += 0.01

# Phase 1: Transient Spin-up
# We integrate for 100 MTU to shed transient features and let planetary waves form natively.
print("  ↳ Executing 100 MTU spin-up phase to construct the chaotic manifold...")
t_spin96, X_spin96 = integrate_lorenz96(state0_96, [0, 100], L96_DT_ML, F=L96_F)

# CRITICAL MANIFOLD FIX: Extract the final state vector of the spin-up
# to serve as our legitimate, physical starting seed for the production run.
attractor_docked_state_96 = X_spin96[-1, :]
print("  ↳ Spin-up complete. System successfully stabilized onto the attractor.")

# Phase 2: Production Data Accumulation Run
# 5,000 MTU evaluated at Delta t = 0.05 yields exactly 100,000 spatial snapshots.
t96, X96 = integrate_lorenz96(attractor_docked_state_96, [0, 5000], L96_DT_ML, F=L96_F)

# -----------------------------------------------------------------------------
# 📊 Diagnostics Verification Matrix
# -----------------------------------------------------------------------------
print("\n📊 Dataset Verification Matrix:")
print("--------------------------------------------------")
print(f"  • Total Temporal Steps : {len(t96):,}")
print(f"  • Total Simulated Time : {t96[-1]:,.1f} Mean Time Units (MTU)")
print(f"  • Tensor Spatial Shape : {X96.shape} (Steps × Grid Points)")
print("--------------------------------------------------")
print(f"  • Domain Absolute Bounds  : [{X96.min():.2f}, {X96.max():.2f}]")
print(f"  • Ensemble Trajectory Mean: {X96.mean():.4f}  (Theoretical Baseline ≈ 2.38 for F=8)")
print("--------------------------------------------------")
print("✓ Lorenz 96 spatial ground truth compiled and locked in memory.")
# Out:
# ⏳ Initializing Lorenz 96 Data Generation (Grid Points N = 40)...
#   ↳ Executing 100 MTU spin-up phase to construct the chaotic manifold...
#   ↳ Spin-up complete. System successfully stabilized onto the attractor.
#
# 📊 Dataset Verification Matrix:
# --------------------------------------------------
#   • Total Temporal Steps : 100,000
#   • Total Simulated Time : 5,000.0 Mean Time Units (MTU)
#   • Tensor Spatial Shape : (100000, 40) (Steps × Grid Points)
# --------------------------------------------------
#   • Domain Absolute Bounds  : [-10.88, 16.56]
#   • Ensemble Trajectory Mean: 2.3400  (Theoretical Baseline ≈ 2.38 for F=8)
# --------------------------------------------------
# ✓ Lorenz 96 spatial ground truth compiled and locked in memory.

# %%
# =============================================================================
# 📊 DATA PARTITIONING & STABILIZED Z-SCORE NORMALIZATION
# =============================================================================

def split_data(X, train_frac=0.50, val_frac=0.25):
    """
    Splits a continuous time-series matrix into chronological, non-overlapping
    blocks for training, validation, and testing to preserve temporal dynamics.
    
    Parameters:
        X (ndarray): Source feature array of shape (n_samples, n_features).
        train_frac (float): Proportion of data allocated for training.
        val_frac (float): Proportion of data allocated for validation.
        
    Returns:
        X_train, X_val, X_test (ndarrays)
    """
    n = len(X)
    n_train = int(n * train_frac)
    n_val   = int(n * val_frac)
    
    X_train = X[:n_train]
    X_val   = X[n_train:n_train + n_val]
    X_test  = X[n_train + n_val:]
    
    return X_train, X_val, X_test


def normalize(X_train, X_val, X_test):
    """
    Computes Z-score normalization statistics strictly from the training set,
    and applies them uniformly across all partitions to prevent data leakage.
    
    Includes a numerical stability guard (epsilon) against division-by-zero.
    """
    mu  = X_train.mean(axis=0)
    sig = X_train.std(axis=0)
    
    # Defensive epsilon guard to protect against stable/zero-variance channels
    eps = 1e-15
    
    X_train_scaled = (X_train - mu) / (sig + eps)
    X_val_scaled   = (X_val - mu) / (sig + eps)
    X_test_scaled  = (X_test - mu) / (sig + eps)
    
    return X_train_scaled, X_val_scaled, X_test_scaled, mu, sig

# -----------------------------------------------------------------------------
# 🌐 Execution: Lorenz 96 Splitting & Normalization
# -----------------------------------------------------------------------------
TR_F, VA_F = 0.50, 0.25
TE_F = 1.0 - (TR_F + VA_F)
X96_train, X96_val, X96_test = split_data(X96, train_frac=TR_F, val_frac=VA_F)
X96_train_n, X96_val_n, X96_test_n, mu96, sig96 = normalize(X96_train, X96_val, X96_test)

print("\n📊 Lorenz 96 Spatiotemporal Splits:")
print("--------------------------------------------------")
print(f"  • Train Set : {X96_train.shape} ({TR_F*100:.0f}%)")
print(f"  • Val Set   : {X96_val.shape}  ({VA_F*100:.0f}%)")
print(f"  • Test Set  : {X96_test.shape} ({TE_F*100:.0f}%)")
print(f"  • Mu (Train, first 3 points)   : {mu96[:3].round(3)}")
print(f"  • Sigma (Train, first 3 points): {sig96[:3].round(3)}")
print("--------------------------------------------------")
print("✓ Chronological splitting completed. Feature arrays scaled and locked.")
# Out:
# 📊 Lorenz 96 Spatiotemporal Splits:
# --------------------------------------------------
#   • Train Set : (50000, 40) (50%)
#   • Val Set   : (25000, 40)  (25%)
#   • Test Set  : (25000, 40) (25%)
#   • Mu (Train, first 3 points)   : [2.309 2.334 2.338]
#   • Sigma (Train, first 3 points): [3.626 3.65  3.67 ]
# --------------------------------------------------
# ✓ Chronological splitting completed. Feature arrays scaled and locked.

# %%
# =============================================================================
# 📊 STEP 1.5: COMPREHENSIVE DATASET DIAGNOSTIC DASHBOARD
# =============================================================================

# Define a unified high-contrast color palette for data partitioning
colors_split = ['#2196F3', '#FF9800', '#4CAF50']  # Blue (Train), Orange (Val), Green (Test)

# Calculate exact percentages dynamically to reflect upstream splits accurately
total_96 = len(X96)
p96_tr, p96_va, p96_te = len(X96_train)/total_96*100, len(X96_val)/total_96*100, len(X96_test)/total_96*100

# Initialize structural canvas
fig = plt.figure(figsize=(7, 15))
fig.suptitle("Step 1: Physical Data Generation Summary Suite", fontsize=16, fontweight='bold', y=0.98)

# -----------------------------------------------------------------------------
# ── Panel 1: L96 Spatiotemporal Hovmöller Diagram
# -----------------------------------------------------------------------------
ax4 = fig.add_subplot(311)
t_end_hov = 500  # Captures the first 25 MTU for spatial propagation mapping
hov = ax4.contourf(np.arange(1, L96_N + 1), t96[:t_end_hov], X96[:t_end_hov, :],
                   levels=30, cmap='RdBu_r', extend='both')
cbar = plt.colorbar(hov, ax=ax4, pad=0.02)
cbar.set_label('State Intensity Value', fontsize=9)
cbar.ax.tick_params(labelsize=8)

ax4.set_xlabel('Spatial Grid Index ($x_1 \dots x_{40}$)', fontsize=10)
ax4.set_ylabel('Time (MTU)', fontsize=10)
ax4.set_title('Lorenz 96: Spatiotemporal Hovmöller Diagram\n(Atmospheric Wave Propagation Circulations)', fontsize=11)

# -----------------------------------------------------------------------------
# ── Panel 2: L96 Grid Coordinate Points
# -----------------------------------------------------------------------------
ax5 = fig.add_subplot(312)
t_plot_lim_96 = 400  # Captures first 20 MTU at Delta t = 0.05
target_channels = [0, 10, 20, 30]
line_colors = ['steelblue', 'darkorange', 'seagreen', 'crimson']

for idx, col in zip(target_channels, line_colors):
    ax5.plot(t96[:t_plot_lim_96], X96[:t_plot_lim_96, idx], color=col, lw=0.9, label=f'Grid Point $x_{{{idx+1}}}$')

# CRITICAL FIX: Moved configuration attributes outside the plotting loop
ax5.set_xlabel('Time (MTU)', fontsize=10)
ax5.set_ylabel('State Magnitude', fontsize=10)
ax5.set_title('Lorenz 96: Core Boundary Velocities\n(Selected Grid Points)', fontsize=11)
ax5.legend(loc='lower left', fontsize=8, ncol=2, framealpha=0.9)
ax5.grid(True, linestyle='--', alpha=0.5)

# -----------------------------------------------------------------------------
# ── Panel 3: L96 Spatiotemporal Data Partitioning
# -----------------------------------------------------------------------------
ax6 = fig.add_subplot(313)
sizes96 = [len(X96_train), len(X96_val), len(X96_test)]
labels96 = [
    f'Train ({p96_tr:.0f}%, {len(X96_train):,})', 
    f'Val ({p96_va:.0f}%, {len(X96_val):,})', 
    f'Test ({p96_te:.0f}%, {len(X96_test):,})'
]
ax6.pie(sizes96, labels=labels96, colors=colors_split, autopct='%1.0f%%', startangle=90, 
        textprops={'fontsize': 9}, wedgeprops={'alpha': 0.85, 'edgecolor': 'w', 'linewidth': 1})
ax6.set_title('Lorenz 96: Chronological Splits', fontsize=11)

# -----------------------------------------------------------------------------
# ── Canvas Serialization & Output Pipeline
# -----------------------------------------------------------------------------
plt.tight_layout()

# Save image into execution tree directory before displaying to prevent buffer flushing loss
output_filename = 'step1_data_generation.png'
plt.savefig(output_filename, dpi=150, bbox_inches='tight')

# Render inline if running interactively
if mpl.get_backend() != 'Agg':
    plt.show()
else:
    plt.close(fig)  # Explicitly clear memory handles on headless environments

print(f"✓ Diagnostic visualization suite compiled successfully. Frame locked in file: '{output_filename}'")
# Out:
# ✓ Diagnostic visualization suite compiled successfully. Frame locked in file: 'step1_data_generation.png'

# %%
# =============================================================================
# 📐 STEP 2: EFFICIENT SLIDING WINDOW DATA ENGINEERING TENSORS
# =============================================================================

# 2.1 Hyperparameters Mapping
WINDOW  = 10    # Number of past historical time steps used as model input (w)
HORIZON = 1     # Prediction lead time: steps ahead to target forecast (h)


def make_windows(X, w=10, h=1):
    """
    Convert a continuous time series array into (input-window, target-state) pairs.
    Handles both 1D and 2D state arrays deterministically.

    Parameters
    ----------
    X : np.ndarray, shape (T, n_features) or (T,)
        Full chronological time series. T = timesteps, n_features = variables.
    w : int, default=10
        Window length (input lookback history history size).
    h : int, default=1
        Forecasting horizon (exactly how many steps ahead to predict).

    Returns
    -------
    Xw : np.ndarray, shape (n_samples, w, n_features), dtype=np.float32
         Feature windows formatted for deep learning architectures.
    Yw : np.ndarray, shape (n_samples, n_features), dtype=np.float32
         Target states safely shifted by the horizon (h).
    """
    # 1. Create overlapping memory views along the temporal axis (axis 0)
    sv = sliding_window_view(X, w, axis=0)

    if X.ndim == 2:
        # Reorder strides from (samples, features, w) -> (samples, w, features)
        # Match expected deep learning shapes: (batch, time_steps, channels)
        sv = sv.transpose(0, 2, 1)
    else:
        sv = sv[:, np.newaxis]  # 1D single-feature channel fallback

    # 2. Compute total valid windows reserving space for the future forecasting horizon
    n_samples = sv.shape[0] - h

    # 3. Slice and cast features and targets up-front to float32 for accelerated training
    Xw = sv[:n_samples].astype(np.float32)
    
    # FIX: Factor horizon 'h' explicitly into target slicing to prevent misalignments if h > 1
    Yw = X[w + h - 1 : w + h - 1 + n_samples].astype(np.float32)
    
    return Xw, Yw


# =============================================================================
# ⏳ AUTOMATED TRAIN / VAL / TEST WINDOW PROCESSING PIPELINE
# =============================================================================
print("⏳ Restructuring scaled arrays into sliding window tensor pairs...")

# 2.2 Define target mappings loop structures to avoid boilerplate code
systems = {
    "L96": {"train": X96_train_n, "val": X96_val_n, "test": X96_test_n}
}

# 2.3 Process and assign all subsets dynamically into memory variables
X96_win_tr, Y96_tr = make_windows(systems["L96"]["train"], WINDOW, HORIZON)
X96_win_vl, Y96_vl = make_windows(systems["L96"]["val"],   WINDOW, HORIZON)
X96_win_te, Y96_te = make_windows(systems["L96"]["test"],  WINDOW, HORIZON)

# Extract final feature channel dimensionality tracking
L96_N = X96_train_n.shape[1]    # 40 (spatial grid zones)

# =============================================================================
# 📊 FINAL GEOMETRY VERIFICATION REPORT
# =============================================================================
print("\n📊 Windowed Data Tensor Verification Matrix:")
print("----------------------------------------------------------------------")
print(f"🌐 Lorenz 96 Train Inputs (Xw) : {X96_win_tr.shape} | Targets (Yw): {Y96_tr.shape}")
print(f"🌐 Lorenz 96 Val Inputs   (Xw) : {X96_win_vl.shape} | Targets (Yw): {Y96_vl.shape}")
print(f"🌐 Lorenz 96 Test Inputs  (Xw) : {X96_win_te.shape} | Targets (Yw): {Y96_te.shape}")
print("----------------------------------------------------------------------")
print("✓ [OK] Step 2 data pipeline finalized. Core shapes ready for training tensors.")
# Out:
# ⏳ Restructuring scaled arrays into sliding window tensor pairs...
#
# 📊 Windowed Data Tensor Verification Matrix:
# ----------------------------------------------------------------------
# 🌐 Lorenz 96 Train Inputs (Xw) : (49990, 10, 40) | Targets (Yw): (49990, 40)
# 🌐 Lorenz 96 Val Inputs   (Xw) : (24990, 10, 40) | Targets (Yw): (24990, 40)
# 🌐 Lorenz 96 Test Inputs  (Xw) : (24990, 10, 40) | Targets (Yw): (24990, 40)
# ----------------------------------------------------------------------
# ✓ [OK] Step 2 data pipeline finalized. Core shapes ready for training tensors.

# %% [markdown]
# # Learning Models

# %%
import itertools

# %%
# =============================================================================
# 🧱 STEP 3: DEEP LEARNING TRAINING PIPELINE
# =============================================================================

def train_and_search(model_builder, 
                     Xtr, Ytr, Xvl, Yvl,
                     BATCH=[128,256,512],
                     L_RATE=[1e-3,1e-4,1e-5],
                     EPOCHS=[5,10,50],
                     name="MLP"):

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    best_global_loss = float("inf")
    best_params = None
    best_state = None

    # Tutte le combinazioni degli iperparametri
    for batch_size, lr, epochs in itertools.product(BATCH, L_RATE, EPOCHS):

        print("\n============================================================")
        print(f"🔍 Testing combination:")
        print(f"   batch_size = {batch_size}")
        print(f"   lr         = {lr}")
        print(f"   epochs     = {epochs}")
        print("============================================================")

        # Ricostruisci un modello nuovo
        model = model_builder().to(device)

        # Optimizer & loss
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)
        criterion = nn.MSELoss()

        # Dataloaders
        train_loader = DataLoader(
            TensorDataset(torch.tensor(Xtr, dtype=torch.float32),
                          torch.tensor(Ytr, dtype=torch.float32)),
            batch_size=batch_size, shuffle=True
        )

        val_loader = DataLoader(
            TensorDataset(torch.tensor(Xvl, dtype=torch.float32),
                          torch.tensor(Yvl, dtype=torch.float32)),
            batch_size=batch_size, shuffle=False
        )

        # Training senza early stopping
        for epoch in range(1, epochs + 1):

            # -------------------------
            # TRAINING
            # -------------------------
            model.train()
            train_losses = []
            for xb, yb in train_loader:
                xb, yb = xb.to(device), yb.to(device)

                optimizer.zero_grad()
                pred = model(xb)
                loss = criterion(pred, yb)
                loss.backward()
                optimizer.step()
                train_losses.append(loss.item())

            train_loss = sum(train_losses) / len(train_losses)

            # -------------------------
            # VALIDATION
            # -------------------------
            model.eval()
            val_losses = []
            with torch.no_grad():
                for xb, yb in val_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    pred = model(xb)
                    val_losses.append(criterion(pred, yb).item())

            val_loss = sum(val_losses) / len(val_losses)

            print(f"Epoch {epoch:03d}/{epochs} | "
                  f"train_loss = {train_loss:.6f} | "
                  f"val_loss = {val_loss:.6f}")

        # Fine training → valutazione finale
        final_val_loss = val_loss
        print(f"→ Final val_loss = {final_val_loss:.6f}")

        # Aggiorna best model globale
        if final_val_loss < best_global_loss:
            best_global_loss = final_val_loss
            best_params = (batch_size, lr, epochs)
            best_state = model.state_dict()
            print("⭐ New best model found!")

    # Salva il best model globale
    torch.save(best_state, f"{name}_BEST.pt")

    print("\n============================================================")
    print("🏆 BEST MODEL FOUND")
    print(f"   batch_size = {best_params[0]}")
    print(f"   lr         = {best_params[1]}")
    print(f"   epochs     = {best_params[2]}")
    print(f"   best val_loss = {best_global_loss:.6f}")
    print(f"   Saved as: {name}_BEST.pt")
    print("============================================================")

    return best_state, best_params, best_global_loss

# %%
# =============================================================================
print('\n⏳ Step 3.1: Mlp...')

class MLP(nn.Module):
    def __init__(self, n_features, window):
        super().__init__()
        self.flatten = nn.Flatten()
        self.net = nn.Sequential(
            nn.Linear(window * n_features, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, n_features)
        )

    def forward(self, x):
        x = self.flatten(x)
        return self.net(x)

# =============================================================================
# ⏳ PIPELINE EXECUTION LOOP
# =============================================================================
model_builder = lambda: MLP(n_features=L96_N, window=WINDOW)
print('\n🏗️  Training MLP...')
mlp, mlp_params, mlp_loss = train_and_search(
    model_builder,
    X96_win_tr, Y96_tr,
    X96_win_vl, Y96_vl,
    name="MLP"
)
# Out:
# ⏳ Step 3.1: Mlp...
#
# 🏗️  Training MLP...
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 0.001
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.193803 | val_loss = 0.060158
# Epoch 002/5 | train_loss = 0.040629 | val_loss = 0.034068
# Epoch 003/5 | train_loss = 0.026485 | val_loss = 0.025470
# Epoch 004/5 | train_loss = 0.020428 | val_loss = 0.020313
# Epoch 005/5 | train_loss = 0.016980 | val_loss = 0.017316
# → Final val_loss = 0.017316
# ⭐ New best model found!
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 0.001
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.195555 | val_loss = 0.060797
# Epoch 002/10 | train_loss = 0.040972 | val_loss = 0.034399
# Epoch 003/10 | train_loss = 0.026715 | val_loss = 0.024825
# Epoch 004/10 | train_loss = 0.020624 | val_loss = 0.020818
# Epoch 005/10 | train_loss = 0.017231 | val_loss = 0.017473
# Epoch 006/10 | train_loss = 0.014810 | val_loss = 0.015110
# Epoch 007/10 | train_loss = 0.012972 | val_loss = 0.013406
# Epoch 008/10 | train_loss = 0.011762 | val_loss = 0.012945
# Epoch 009/10 | train_loss = 0.010580 | val_loss = 0.012175
# Epoch 010/10 | train_loss = 0.009830 | val_loss = 0.010634
# → Final val_loss = 0.010634
# ⭐ New best model found!
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 0.001
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.199305 | val_loss = 0.060554
# Epoch 002/50 | train_loss = 0.040746 | val_loss = 0.035255
# Epoch 003/50 | train_loss = 0.026432 | val_loss = 0.025764
# Epoch 004/50 | train_loss = 0.020261 | val_loss = 0.020574
# Epoch 005/50 | train_loss = 0.016737 | val_loss = 0.018041
# Epoch 006/50 | train_loss = 0.014410 | val_loss = 0.015210
# Epoch 007/50 | train_loss = 0.012844 | val_loss = 0.013611
# Epoch 008/50 | train_loss = 0.011379 | val_loss = 0.011913
# Epoch 009/50 | train_loss = 0.010331 | val_loss = 0.010792
# Epoch 010/50 | train_loss = 0.009535 | val_loss = 0.010580
# Epoch 011/50 | train_loss = 0.008933 | val_loss = 0.009293
# Epoch 012/50 | train_loss = 0.008468 | val_loss = 0.009740
# Epoch 013/50 | train_loss = 0.007856 | val_loss = 0.008379
# Epoch 014/50 | train_loss = 0.007511 | val_loss = 0.008766
# Epoch 015/50 | train_loss = 0.007070 | val_loss = 0.008216
# Epoch 016/50 | train_loss = 0.006756 | val_loss = 0.007588
# Epoch 017/50 | train_loss = 0.006638 | val_loss = 0.006987
# Epoch 018/50 | train_loss = 0.006355 | val_loss = 0.007162
# Epoch 019/50 | train_loss = 0.005999 | val_loss = 0.006363
# Epoch 020/50 | train_loss = 0.005876 | val_loss = 0.006203
# Epoch 021/50 | train_loss = 0.005592 | val_loss = 0.006130
# Epoch 022/50 | train_loss = 0.005549 | val_loss = 0.005827
# Epoch 023/50 | train_loss = 0.005371 | val_loss = 0.005966
# Epoch 024/50 | train_loss = 0.005286 | val_loss = 0.005952
# Epoch 025/50 | train_loss = 0.005209 | val_loss = 0.006148
# Epoch 026/50 | train_loss = 0.004970 | val_loss = 0.005233
# Epoch 027/50 | train_loss = 0.004887 | val_loss = 0.005924
# Epoch 028/50 | train_loss = 0.004788 | val_loss = 0.005638
# Epoch 029/50 | train_loss = 0.004750 | val_loss = 0.005424
# Epoch 030/50 | train_loss = 0.004652 | val_loss = 0.004635
# Epoch 031/50 | train_loss = 0.004539 | val_loss = 0.004828
# Epoch 032/50 | train_loss = 0.004487 | val_loss = 0.005028
# Epoch 033/50 | train_loss = 0.004365 | val_loss = 0.004544
# Epoch 034/50 | train_loss = 0.004186 | val_loss = 0.005275
# Epoch 035/50 | train_loss = 0.004223 | val_loss = 0.004867
# Epoch 036/50 | train_loss = 0.004182 | val_loss = 0.004635
# Epoch 037/50 | train_loss = 0.004121 | val_loss = 0.004691
# Epoch 038/50 | train_loss = 0.004002 | val_loss = 0.004526
# Epoch 039/50 | train_loss = 0.004020 | val_loss = 0.004587
# Epoch 040/50 | train_loss = 0.003932 | val_loss = 0.005207
# Epoch 041/50 | train_loss = 0.003868 | val_loss = 0.004881
# Epoch 042/50 | train_loss = 0.003835 | val_loss = 0.004682
# Epoch 043/50 | train_loss = 0.003827 | val_loss = 0.003965
# Epoch 044/50 | train_loss = 0.003796 | val_loss = 0.004212
# Epoch 045/50 | train_loss = 0.003758 | val_loss = 0.004650
# Epoch 046/50 | train_loss = 0.003667 | val_loss = 0.003912
# Epoch 047/50 | train_loss = 0.003638 | val_loss = 0.004915
# Epoch 048/50 | train_loss = 0.003531 | val_loss = 0.003756
# Epoch 049/50 | train_loss = 0.003603 | val_loss = 0.004191
# Epoch 050/50 | train_loss = 0.003490 | val_loss = 0.003888
# → Final val_loss = 0.003888
# ⭐ New best model found!
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 0.0001
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.594393 | val_loss = 0.342002
# Epoch 002/5 | train_loss = 0.247616 | val_loss = 0.189142
# Epoch 003/5 | train_loss = 0.145092 | val_loss = 0.123370
# Epoch 004/5 | train_loss = 0.098427 | val_loss = 0.090812
# Epoch 005/5 | train_loss = 0.074852 | val_loss = 0.073120
# → Final val_loss = 0.073120
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 0.0001
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.578643 | val_loss = 0.324707
# Epoch 002/10 | train_loss = 0.235176 | val_loss = 0.178181
# Epoch 003/10 | train_loss = 0.135464 | val_loss = 0.115024
# Epoch 004/10 | train_loss = 0.093026 | val_loss = 0.086861
# Epoch 005/10 | train_loss = 0.071851 | val_loss = 0.070304
# Epoch 006/10 | train_loss = 0.058570 | val_loss = 0.059026
# Epoch 007/10 | train_loss = 0.049242 | val_loss = 0.050710
# Epoch 008/10 | train_loss = 0.042390 | val_loss = 0.044583
# Epoch 009/10 | train_loss = 0.037138 | val_loss = 0.039450
# Epoch 010/10 | train_loss = 0.033026 | val_loss = 0.035292
# → Final val_loss = 0.035292
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 0.0001
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.587740 | val_loss = 0.334799
# Epoch 002/50 | train_loss = 0.243260 | val_loss = 0.185113
# Epoch 003/50 | train_loss = 0.141120 | val_loss = 0.119460
# Epoch 004/50 | train_loss = 0.095750 | val_loss = 0.089160
# Epoch 005/50 | train_loss = 0.073497 | val_loss = 0.071720
# Epoch 006/50 | train_loss = 0.059798 | val_loss = 0.060412
# Epoch 007/50 | train_loss = 0.050306 | val_loss = 0.051906
# Epoch 008/50 | train_loss = 0.043316 | val_loss = 0.045407
# Epoch 009/50 | train_loss = 0.037988 | val_loss = 0.040540
# Epoch 010/50 | train_loss = 0.033825 | val_loss = 0.036300
# Epoch 011/50 | train_loss = 0.030452 | val_loss = 0.032971
# Epoch 012/50 | train_loss = 0.027631 | val_loss = 0.030201
# Epoch 013/50 | train_loss = 0.025297 | val_loss = 0.027650
# Epoch 014/50 | train_loss = 0.023287 | val_loss = 0.025511
# Epoch 015/50 | train_loss = 0.021581 | val_loss = 0.023863
# Epoch 016/50 | train_loss = 0.020088 | val_loss = 0.022382
# Epoch 017/50 | train_loss = 0.018759 | val_loss = 0.020878
# Epoch 018/50 | train_loss = 0.017608 | val_loss = 0.019514
# Epoch 019/50 | train_loss = 0.016557 | val_loss = 0.018646
# Epoch 020/50 | train_loss = 0.015644 | val_loss = 0.017547
# Epoch 021/50 | train_loss = 0.014789 | val_loss = 0.016632
# Epoch 022/50 | train_loss = 0.014018 | val_loss = 0.015718
# Epoch 023/50 | train_loss = 0.013310 | val_loss = 0.015066
# Epoch 024/50 | train_loss = 0.012689 | val_loss = 0.014454
# Epoch 025/50 | train_loss = 0.012091 | val_loss = 0.013608
# Epoch 026/50 | train_loss = 0.011527 | val_loss = 0.013050
# Epoch 027/50 | train_loss = 0.011028 | val_loss = 0.012485
# Epoch 028/50 | train_loss = 0.010550 | val_loss = 0.012047
# Epoch 029/50 | train_loss = 0.010075 | val_loss = 0.011463
# Epoch 030/50 | train_loss = 0.009665 | val_loss = 0.011067
# Epoch 031/50 | train_loss = 0.009267 | val_loss = 0.010407
# Epoch 032/50 | train_loss = 0.008888 | val_loss = 0.010196
# Epoch 033/50 | train_loss = 0.008557 | val_loss = 0.009748
# Epoch 034/50 | train_loss = 0.008218 | val_loss = 0.009434
# Epoch 035/50 | train_loss = 0.007897 | val_loss = 0.008886
# Epoch 036/50 | train_loss = 0.007600 | val_loss = 0.008710
# Epoch 037/50 | train_loss = 0.007306 | val_loss = 0.008332
# Epoch 038/50 | train_loss = 0.007038 | val_loss = 0.008008
# Epoch 039/50 | train_loss = 0.006789 | val_loss = 0.007702
# Epoch 040/50 | train_loss = 0.006556 | val_loss = 0.007408
# Epoch 041/50 | train_loss = 0.006322 | val_loss = 0.007314
# Epoch 042/50 | train_loss = 0.006102 | val_loss = 0.007002
# Epoch 043/50 | train_loss = 0.005896 | val_loss = 0.006687
# Epoch 044/50 | train_loss = 0.005694 | val_loss = 0.006515
# Epoch 045/50 | train_loss = 0.005511 | val_loss = 0.006350
# Epoch 046/50 | train_loss = 0.005346 | val_loss = 0.006071
# Epoch 047/50 | train_loss = 0.005162 | val_loss = 0.005959
# Epoch 048/50 | train_loss = 0.004999 | val_loss = 0.005705
# Epoch 049/50 | train_loss = 0.004862 | val_loss = 0.005652
# Epoch 050/50 | train_loss = 0.004710 | val_loss = 0.005367
# → Final val_loss = 0.005367
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 1e-05
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.976364 | val_loss = 0.931934
# Epoch 002/5 | train_loss = 0.862927 | val_loss = 0.771672
# Epoch 003/5 | train_loss = 0.702321 | val_loss = 0.637253
# Epoch 004/5 | train_loss = 0.598291 | val_loss = 0.557274
# Epoch 005/5 | train_loss = 0.528771 | val_loss = 0.499479
# → Final val_loss = 0.499479
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 1e-05
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.980070 | val_loss = 0.940606
# Epoch 002/10 | train_loss = 0.878301 | val_loss = 0.791264
# Epoch 003/10 | train_loss = 0.716536 | val_loss = 0.643145
# Epoch 004/10 | train_loss = 0.601448 | val_loss = 0.559471
# Epoch 005/10 | train_loss = 0.530562 | val_loss = 0.501588
# Epoch 006/10 | train_loss = 0.477730 | val_loss = 0.456274
# Epoch 007/10 | train_loss = 0.435219 | val_loss = 0.418986
# Epoch 008/10 | train_loss = 0.400039 | val_loss = 0.387674
# Epoch 009/10 | train_loss = 0.370061 | val_loss = 0.360715
# Epoch 010/10 | train_loss = 0.344064 | val_loss = 0.336956
# → Final val_loss = 0.336956
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 1e-05
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.979902 | val_loss = 0.940360
# Epoch 002/50 | train_loss = 0.872524 | val_loss = 0.778440
# Epoch 003/50 | train_loss = 0.705536 | val_loss = 0.633349
# Epoch 004/50 | train_loss = 0.593946 | val_loss = 0.549830
# Epoch 005/50 | train_loss = 0.522812 | val_loss = 0.491858
# Epoch 006/50 | train_loss = 0.470431 | val_loss = 0.447893
# Epoch 007/50 | train_loss = 0.429442 | val_loss = 0.412483
# Epoch 008/50 | train_loss = 0.395601 | val_loss = 0.382335
# Epoch 009/50 | train_loss = 0.366503 | val_loss = 0.355978
# Epoch 010/50 | train_loss = 0.340772 | val_loss = 0.332410
# Epoch 011/50 | train_loss = 0.317676 | val_loss = 0.311220
# Epoch 012/50 | train_loss = 0.296881 | val_loss = 0.291852
# Epoch 013/50 | train_loss = 0.278009 | val_loss = 0.274341
# Epoch 014/50 | train_loss = 0.260738 | val_loss = 0.258066
# Epoch 015/50 | train_loss = 0.244853 | val_loss = 0.243199
# Epoch 016/50 | train_loss = 0.230243 | val_loss = 0.229374
# Epoch 017/50 | train_loss = 0.216755 | val_loss = 0.216611
# Epoch 018/50 | train_loss = 0.204295 | val_loss = 0.204829
# Epoch 019/50 | train_loss = 0.192729 | val_loss = 0.193833
# Epoch 020/50 | train_loss = 0.182061 | val_loss = 0.183631
# Epoch 021/50 | train_loss = 0.172154 | val_loss = 0.174142
# Epoch 022/50 | train_loss = 0.162976 | val_loss = 0.165427
# Epoch 023/50 | train_loss = 0.154484 | val_loss = 0.157251
# Epoch 024/50 | train_loss = 0.146614 | val_loss = 0.149692
# Epoch 025/50 | train_loss = 0.139360 | val_loss = 0.142741
# Epoch 026/50 | train_loss = 0.132684 | val_loss = 0.136344
# Epoch 027/50 | train_loss = 0.126521 | val_loss = 0.130459
# Epoch 028/50 | train_loss = 0.120845 | val_loss = 0.124938
# Epoch 029/50 | train_loss = 0.115626 | val_loss = 0.119926
# Epoch 030/50 | train_loss = 0.110815 | val_loss = 0.115325
# Epoch 031/50 | train_loss = 0.106343 | val_loss = 0.110992
# Epoch 032/50 | train_loss = 0.102213 | val_loss = 0.106951
# Epoch 033/50 | train_loss = 0.098382 | val_loss = 0.103326
# Epoch 034/50 | train_loss = 0.094790 | val_loss = 0.099805
# Epoch 035/50 | train_loss = 0.091463 | val_loss = 0.096560
# Epoch 036/50 | train_loss = 0.088367 | val_loss = 0.093580
# Epoch 037/50 | train_loss = 0.085480 | val_loss = 0.090786
# Epoch 038/50 | train_loss = 0.082788 | val_loss = 0.088131
# Epoch 039/50 | train_loss = 0.080252 | val_loss = 0.085657
# Epoch 040/50 | train_loss = 0.077884 | val_loss = 0.083317
# Epoch 041/50 | train_loss = 0.075649 | val_loss = 0.081113
# Epoch 042/50 | train_loss = 0.073539 | val_loss = 0.079039
# Epoch 043/50 | train_loss = 0.071543 | val_loss = 0.077069
# Epoch 044/50 | train_loss = 0.069636 | val_loss = 0.075155
# Epoch 045/50 | train_loss = 0.067825 | val_loss = 0.073390
# Epoch 046/50 | train_loss = 0.066103 | val_loss = 0.071687
# Epoch 047/50 | train_loss = 0.064446 | val_loss = 0.069993
# Epoch 048/50 | train_loss = 0.062869 | val_loss = 0.068456
# Epoch 049/50 | train_loss = 0.061358 | val_loss = 0.066901
# Epoch 050/50 | train_loss = 0.059909 | val_loss = 0.065416
# → Final val_loss = 0.065416
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 0.001
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.278677 | val_loss = 0.091826
# Epoch 002/5 | train_loss = 0.059535 | val_loss = 0.048068
# Epoch 003/5 | train_loss = 0.036098 | val_loss = 0.033776
# Epoch 004/5 | train_loss = 0.026928 | val_loss = 0.027137
# Epoch 005/5 | train_loss = 0.021815 | val_loss = 0.022513
# → Final val_loss = 0.022513
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 0.001
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.277115 | val_loss = 0.093609
# Epoch 002/10 | train_loss = 0.059023 | val_loss = 0.049018
# Epoch 003/10 | train_loss = 0.036178 | val_loss = 0.034851
# Epoch 004/10 | train_loss = 0.026987 | val_loss = 0.027270
# Epoch 005/10 | train_loss = 0.022140 | val_loss = 0.023621
# Epoch 006/10 | train_loss = 0.018793 | val_loss = 0.020480
# Epoch 007/10 | train_loss = 0.016465 | val_loss = 0.017654
# Epoch 008/10 | train_loss = 0.014727 | val_loss = 0.016110
# Epoch 009/10 | train_loss = 0.013261 | val_loss = 0.014902
# Epoch 010/10 | train_loss = 0.012025 | val_loss = 0.013088
# → Final val_loss = 0.013088
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 0.001
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.283461 | val_loss = 0.094376
# Epoch 002/50 | train_loss = 0.060088 | val_loss = 0.048802
# Epoch 003/50 | train_loss = 0.036936 | val_loss = 0.035708
# Epoch 004/50 | train_loss = 0.027565 | val_loss = 0.027445
# Epoch 005/50 | train_loss = 0.022373 | val_loss = 0.023887
# Epoch 006/50 | train_loss = 0.019125 | val_loss = 0.020789
# Epoch 007/50 | train_loss = 0.016791 | val_loss = 0.018232
# Epoch 008/50 | train_loss = 0.014864 | val_loss = 0.017019
# Epoch 009/50 | train_loss = 0.013283 | val_loss = 0.015221
# Epoch 010/50 | train_loss = 0.012180 | val_loss = 0.013885
# Epoch 011/50 | train_loss = 0.011269 | val_loss = 0.012003
# Epoch 012/50 | train_loss = 0.010369 | val_loss = 0.011349
# Epoch 013/50 | train_loss = 0.009516 | val_loss = 0.011013
# Epoch 014/50 | train_loss = 0.008988 | val_loss = 0.009944
# Epoch 015/50 | train_loss = 0.008397 | val_loss = 0.009767
# Epoch 016/50 | train_loss = 0.008024 | val_loss = 0.008782
# Epoch 017/50 | train_loss = 0.007495 | val_loss = 0.008793
# Epoch 018/50 | train_loss = 0.007183 | val_loss = 0.008741
# Epoch 019/50 | train_loss = 0.006822 | val_loss = 0.007976
# Epoch 020/50 | train_loss = 0.006486 | val_loss = 0.007094
# Epoch 021/50 | train_loss = 0.006371 | val_loss = 0.008087
# Epoch 022/50 | train_loss = 0.006024 | val_loss = 0.006871
# Epoch 023/50 | train_loss = 0.005775 | val_loss = 0.007011
# Epoch 024/50 | train_loss = 0.005582 | val_loss = 0.006493
# Epoch 025/50 | train_loss = 0.005335 | val_loss = 0.005689
# Epoch 026/50 | train_loss = 0.005236 | val_loss = 0.006405
# Epoch 027/50 | train_loss = 0.004995 | val_loss = 0.005823
# Epoch 028/50 | train_loss = 0.004915 | val_loss = 0.006119
# Epoch 029/50 | train_loss = 0.004727 | val_loss = 0.005762
# Epoch 030/50 | train_loss = 0.004682 | val_loss = 0.005608
# Epoch 031/50 | train_loss = 0.004644 | val_loss = 0.005391
# Epoch 032/50 | train_loss = 0.004358 | val_loss = 0.005040
# Epoch 033/50 | train_loss = 0.004376 | val_loss = 0.005413
# Epoch 034/50 | train_loss = 0.004245 | val_loss = 0.004513
# Epoch 035/50 | train_loss = 0.004037 | val_loss = 0.004670
# Epoch 036/50 | train_loss = 0.004110 | val_loss = 0.004883
# Epoch 037/50 | train_loss = 0.004047 | val_loss = 0.005342
# Epoch 038/50 | train_loss = 0.003974 | val_loss = 0.004345
# Epoch 039/50 | train_loss = 0.003877 | val_loss = 0.004813
# Epoch 040/50 | train_loss = 0.003764 | val_loss = 0.004428
# Epoch 041/50 | train_loss = 0.003645 | val_loss = 0.003982
# Epoch 042/50 | train_loss = 0.003645 | val_loss = 0.004462
# Epoch 043/50 | train_loss = 0.003677 | val_loss = 0.004541
# Epoch 044/50 | train_loss = 0.003537 | val_loss = 0.004605
# Epoch 045/50 | train_loss = 0.003429 | val_loss = 0.005765
# Epoch 046/50 | train_loss = 0.003622 | val_loss = 0.003931
# Epoch 047/50 | train_loss = 0.003534 | val_loss = 0.004260
# Epoch 048/50 | train_loss = 0.003372 | val_loss = 0.003976
# Epoch 049/50 | train_loss = 0.003353 | val_loss = 0.003845
# Epoch 050/50 | train_loss = 0.003291 | val_loss = 0.004290
# → Final val_loss = 0.004290
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 0.0001
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.728056 | val_loss = 0.465121
# Epoch 002/5 | train_loss = 0.363140 | val_loss = 0.289917
# Epoch 003/5 | train_loss = 0.233854 | val_loss = 0.199610
# Epoch 004/5 | train_loss = 0.163256 | val_loss = 0.146469
# Epoch 005/5 | train_loss = 0.121823 | val_loss = 0.114897
# → Final val_loss = 0.114897
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 0.0001
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.728649 | val_loss = 0.464287
# Epoch 002/10 | train_loss = 0.364978 | val_loss = 0.293595
# Epoch 003/10 | train_loss = 0.238104 | val_loss = 0.203772
# Epoch 004/10 | train_loss = 0.167507 | val_loss = 0.150059
# Epoch 005/10 | train_loss = 0.124723 | val_loss = 0.116378
# Epoch 006/10 | train_loss = 0.098497 | val_loss = 0.095533
# Epoch 007/10 | train_loss = 0.081952 | val_loss = 0.081913
# Epoch 008/10 | train_loss = 0.070284 | val_loss = 0.071564
# Epoch 009/10 | train_loss = 0.061459 | val_loss = 0.063599
# Epoch 010/10 | train_loss = 0.054490 | val_loss = 0.057142
# → Final val_loss = 0.057142
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 0.0001
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.726137 | val_loss = 0.471460
# Epoch 002/50 | train_loss = 0.366506 | val_loss = 0.293163
# Epoch 003/50 | train_loss = 0.237791 | val_loss = 0.202915
# Epoch 004/50 | train_loss = 0.166286 | val_loss = 0.148380
# Epoch 005/50 | train_loss = 0.123294 | val_loss = 0.115441
# Epoch 006/50 | train_loss = 0.097486 | val_loss = 0.095215
# Epoch 007/50 | train_loss = 0.081133 | val_loss = 0.081387
# Epoch 008/50 | train_loss = 0.069665 | val_loss = 0.071367
# Epoch 009/50 | train_loss = 0.061002 | val_loss = 0.063311
# Epoch 010/50 | train_loss = 0.054141 | val_loss = 0.057098
# Epoch 011/50 | train_loss = 0.048674 | val_loss = 0.051739
# Epoch 012/50 | train_loss = 0.044203 | val_loss = 0.047481
# Epoch 013/50 | train_loss = 0.040444 | val_loss = 0.043723
# Epoch 014/50 | train_loss = 0.037287 | val_loss = 0.040525
# Epoch 015/50 | train_loss = 0.034534 | val_loss = 0.037846
# Epoch 016/50 | train_loss = 0.032187 | val_loss = 0.035379
# Epoch 017/50 | train_loss = 0.030107 | val_loss = 0.033295
# Epoch 018/50 | train_loss = 0.028277 | val_loss = 0.031459
# Epoch 019/50 | train_loss = 0.026629 | val_loss = 0.029599
# Epoch 020/50 | train_loss = 0.025175 | val_loss = 0.028278
# Epoch 021/50 | train_loss = 0.023867 | val_loss = 0.026765
# Epoch 022/50 | train_loss = 0.022643 | val_loss = 0.025422
# Epoch 023/50 | train_loss = 0.021521 | val_loss = 0.024285
# Epoch 024/50 | train_loss = 0.020546 | val_loss = 0.023255
# Epoch 025/50 | train_loss = 0.019619 | val_loss = 0.022185
# Epoch 026/50 | train_loss = 0.018763 | val_loss = 0.021326
# Epoch 027/50 | train_loss = 0.017972 | val_loss = 0.020398
# Epoch 028/50 | train_loss = 0.017234 | val_loss = 0.019646
# Epoch 029/50 | train_loss = 0.016570 | val_loss = 0.018786
# Epoch 030/50 | train_loss = 0.015919 | val_loss = 0.018181
# Epoch 031/50 | train_loss = 0.015324 | val_loss = 0.017604
# Epoch 032/50 | train_loss = 0.014762 | val_loss = 0.016850
# Epoch 033/50 | train_loss = 0.014237 | val_loss = 0.016263
# Epoch 034/50 | train_loss = 0.013716 | val_loss = 0.015833
# Epoch 035/50 | train_loss = 0.013248 | val_loss = 0.015163
# Epoch 036/50 | train_loss = 0.012794 | val_loss = 0.014668
# Epoch 037/50 | train_loss = 0.012373 | val_loss = 0.014211
# Epoch 038/50 | train_loss = 0.011958 | val_loss = 0.013885
# Epoch 039/50 | train_loss = 0.011582 | val_loss = 0.013336
# Epoch 040/50 | train_loss = 0.011219 | val_loss = 0.012936
# Epoch 041/50 | train_loss = 0.010862 | val_loss = 0.012511
# Epoch 042/50 | train_loss = 0.010527 | val_loss = 0.012159
# Epoch 043/50 | train_loss = 0.010195 | val_loss = 0.011681
# Epoch 044/50 | train_loss = 0.009871 | val_loss = 0.011352
# Epoch 045/50 | train_loss = 0.009584 | val_loss = 0.011175
# Epoch 046/50 | train_loss = 0.009300 | val_loss = 0.010732
# Epoch 047/50 | train_loss = 0.009022 | val_loss = 0.010440
# Epoch 048/50 | train_loss = 0.008761 | val_loss = 0.010110
# Epoch 049/50 | train_loss = 0.008514 | val_loss = 0.009872
# Epoch 050/50 | train_loss = 0.008258 | val_loss = 0.009529
# → Final val_loss = 0.009529
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 1e-05
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.992019 | val_loss = 0.973581
# Epoch 002/5 | train_loss = 0.954096 | val_loss = 0.918486
# Epoch 003/5 | train_loss = 0.878816 | val_loss = 0.823722
# Epoch 004/5 | train_loss = 0.777336 | val_loss = 0.723079
# Epoch 005/5 | train_loss = 0.687094 | val_loss = 0.646088
# → Final val_loss = 0.646088
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 1e-05
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.993705 | val_loss = 0.975810
# Epoch 002/10 | train_loss = 0.955765 | val_loss = 0.918297
# Epoch 003/10 | train_loss = 0.877292 | val_loss = 0.819268
# Epoch 004/10 | train_loss = 0.774601 | val_loss = 0.718200
# Epoch 005/10 | train_loss = 0.684756 | val_loss = 0.641175
# Epoch 006/10 | train_loss = 0.616429 | val_loss = 0.584161
# Epoch 007/10 | train_loss = 0.564904 | val_loss = 0.540316
# Epoch 008/10 | train_loss = 0.523945 | val_loss = 0.504749
# Epoch 009/10 | train_loss = 0.490318 | val_loss = 0.474873
# Epoch 010/10 | train_loss = 0.461470 | val_loss = 0.448793
# → Final val_loss = 0.448793
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 1e-05
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.993051 | val_loss = 0.973695
# Epoch 002/50 | train_loss = 0.954449 | val_loss = 0.917814
# Epoch 003/50 | train_loss = 0.878973 | val_loss = 0.822785
# Epoch 004/50 | train_loss = 0.778464 | val_loss = 0.722899
# Epoch 005/50 | train_loss = 0.689114 | val_loss = 0.645528
# Epoch 006/50 | train_loss = 0.621403 | val_loss = 0.588553
# Epoch 007/50 | train_loss = 0.570524 | val_loss = 0.544778
# Epoch 008/50 | train_loss = 0.529898 | val_loss = 0.509237
# Epoch 009/50 | train_loss = 0.495975 | val_loss = 0.479263
# Epoch 010/50 | train_loss = 0.466764 | val_loss = 0.453124
# Epoch 011/50 | train_loss = 0.441106 | val_loss = 0.429889
# Epoch 012/50 | train_loss = 0.417995 | val_loss = 0.408809
# Epoch 013/50 | train_loss = 0.397019 | val_loss = 0.389493
# Epoch 014/50 | train_loss = 0.377648 | val_loss = 0.371556
# Epoch 015/50 | train_loss = 0.359815 | val_loss = 0.354929
# Epoch 016/50 | train_loss = 0.343157 | val_loss = 0.339486
# Epoch 017/50 | train_loss = 0.327738 | val_loss = 0.325033
# Epoch 018/50 | train_loss = 0.313269 | val_loss = 0.311401
# Epoch 019/50 | train_loss = 0.299744 | val_loss = 0.298625
# Epoch 020/50 | train_loss = 0.286973 | val_loss = 0.286518
# Epoch 021/50 | train_loss = 0.274995 | val_loss = 0.275083
# Epoch 022/50 | train_loss = 0.263577 | val_loss = 0.264349
# Epoch 023/50 | train_loss = 0.252815 | val_loss = 0.254044
# Epoch 024/50 | train_loss = 0.242677 | val_loss = 0.244314
# Epoch 025/50 | train_loss = 0.233030 | val_loss = 0.235059
# Epoch 026/50 | train_loss = 0.223825 | val_loss = 0.226330
# Epoch 027/50 | train_loss = 0.215079 | val_loss = 0.217980
# Epoch 028/50 | train_loss = 0.206834 | val_loss = 0.210032
# Epoch 029/50 | train_loss = 0.199017 | val_loss = 0.202511
# Epoch 030/50 | train_loss = 0.191515 | val_loss = 0.195291
# Epoch 031/50 | train_loss = 0.184505 | val_loss = 0.188504
# Epoch 032/50 | train_loss = 0.177731 | val_loss = 0.182047
# Epoch 033/50 | train_loss = 0.171381 | val_loss = 0.175884
# Epoch 034/50 | train_loss = 0.165366 | val_loss = 0.170153
# Epoch 035/50 | train_loss = 0.159643 | val_loss = 0.164548
# Epoch 036/50 | train_loss = 0.154251 | val_loss = 0.159349
# Epoch 037/50 | train_loss = 0.149106 | val_loss = 0.154411
# Epoch 038/50 | train_loss = 0.144262 | val_loss = 0.149662
# Epoch 039/50 | train_loss = 0.139657 | val_loss = 0.145225
# Epoch 040/50 | train_loss = 0.135281 | val_loss = 0.140923
# Epoch 041/50 | train_loss = 0.131162 | val_loss = 0.136940
# Epoch 042/50 | train_loss = 0.127251 | val_loss = 0.133088
# Epoch 043/50 | train_loss = 0.123490 | val_loss = 0.129446
# Epoch 044/50 | train_loss = 0.119955 | val_loss = 0.125962
# Epoch 045/50 | train_loss = 0.116595 | val_loss = 0.122714
# Epoch 046/50 | train_loss = 0.113396 | val_loss = 0.119587
# Epoch 047/50 | train_loss = 0.110338 | val_loss = 0.116571
# Epoch 048/50 | train_loss = 0.107450 | val_loss = 0.113741
# Epoch 049/50 | train_loss = 0.104708 | val_loss = 0.111011
# Epoch 050/50 | train_loss = 0.102105 | val_loss = 0.108412
# → Final val_loss = 0.108412
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 0.001
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.403312 | val_loss = 0.162053
# Epoch 002/5 | train_loss = 0.101241 | val_loss = 0.076166
# Epoch 003/5 | train_loss = 0.056943 | val_loss = 0.051848
# Epoch 004/5 | train_loss = 0.040576 | val_loss = 0.039212
# Epoch 005/5 | train_loss = 0.032223 | val_loss = 0.033857
# → Final val_loss = 0.033857
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 0.001
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.402504 | val_loss = 0.162778
# Epoch 002/10 | train_loss = 0.102162 | val_loss = 0.076440
# Epoch 003/10 | train_loss = 0.056483 | val_loss = 0.051744
# Epoch 004/10 | train_loss = 0.040356 | val_loss = 0.038901
# Epoch 005/10 | train_loss = 0.031688 | val_loss = 0.032694
# Epoch 006/10 | train_loss = 0.026602 | val_loss = 0.028205
# Epoch 007/10 | train_loss = 0.023074 | val_loss = 0.024377
# Epoch 008/10 | train_loss = 0.020367 | val_loss = 0.021782
# Epoch 009/10 | train_loss = 0.018452 | val_loss = 0.021724
# Epoch 010/10 | train_loss = 0.016783 | val_loss = 0.018535
# → Final val_loss = 0.018535
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 0.001
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.404288 | val_loss = 0.162444
# Epoch 002/50 | train_loss = 0.100896 | val_loss = 0.075044
# Epoch 003/50 | train_loss = 0.056294 | val_loss = 0.051486
# Epoch 004/50 | train_loss = 0.040377 | val_loss = 0.040126
# Epoch 005/50 | train_loss = 0.031922 | val_loss = 0.032469
# Epoch 006/50 | train_loss = 0.026561 | val_loss = 0.027919
# Epoch 007/50 | train_loss = 0.023182 | val_loss = 0.024447
# Epoch 008/50 | train_loss = 0.020414 | val_loss = 0.022313
# Epoch 009/50 | train_loss = 0.018405 | val_loss = 0.020095
# Epoch 010/50 | train_loss = 0.016713 | val_loss = 0.018533
# Epoch 011/50 | train_loss = 0.015433 | val_loss = 0.017114
# Epoch 012/50 | train_loss = 0.014324 | val_loss = 0.015943
# Epoch 013/50 | train_loss = 0.013357 | val_loss = 0.015121
# Epoch 014/50 | train_loss = 0.012466 | val_loss = 0.013842
# Epoch 015/50 | train_loss = 0.011534 | val_loss = 0.012784
# Epoch 016/50 | train_loss = 0.010936 | val_loss = 0.011988
# Epoch 017/50 | train_loss = 0.010401 | val_loss = 0.011866
# Epoch 018/50 | train_loss = 0.009991 | val_loss = 0.010776
# Epoch 019/50 | train_loss = 0.009287 | val_loss = 0.010956
# Epoch 020/50 | train_loss = 0.008955 | val_loss = 0.010462
# Epoch 021/50 | train_loss = 0.008488 | val_loss = 0.009142
# Epoch 022/50 | train_loss = 0.008080 | val_loss = 0.009418
# Epoch 023/50 | train_loss = 0.007644 | val_loss = 0.008432
# Epoch 024/50 | train_loss = 0.007302 | val_loss = 0.007824
# Epoch 025/50 | train_loss = 0.007197 | val_loss = 0.007900
# Epoch 026/50 | train_loss = 0.006758 | val_loss = 0.007977
# Epoch 027/50 | train_loss = 0.006485 | val_loss = 0.007213
# Epoch 028/50 | train_loss = 0.006385 | val_loss = 0.007259
# Epoch 029/50 | train_loss = 0.006127 | val_loss = 0.007234
# Epoch 030/50 | train_loss = 0.005971 | val_loss = 0.006535
# Epoch 031/50 | train_loss = 0.005700 | val_loss = 0.006207
# Epoch 032/50 | train_loss = 0.005534 | val_loss = 0.006235
# Epoch 033/50 | train_loss = 0.005206 | val_loss = 0.006079
# Epoch 034/50 | train_loss = 0.005222 | val_loss = 0.005835
# Epoch 035/50 | train_loss = 0.005108 | val_loss = 0.005683
# Epoch 036/50 | train_loss = 0.005011 | val_loss = 0.005325
# Epoch 037/50 | train_loss = 0.004791 | val_loss = 0.005223
# Epoch 038/50 | train_loss = 0.004689 | val_loss = 0.005077
# Epoch 039/50 | train_loss = 0.004502 | val_loss = 0.005279
# Epoch 040/50 | train_loss = 0.004418 | val_loss = 0.004782
# Epoch 041/50 | train_loss = 0.004390 | val_loss = 0.005206
# Epoch 042/50 | train_loss = 0.004334 | val_loss = 0.004705
# Epoch 043/50 | train_loss = 0.004204 | val_loss = 0.004746
# Epoch 044/50 | train_loss = 0.004123 | val_loss = 0.004374
# Epoch 045/50 | train_loss = 0.003923 | val_loss = 0.004355
# Epoch 046/50 | train_loss = 0.003925 | val_loss = 0.004437
# Epoch 047/50 | train_loss = 0.003956 | val_loss = 0.004496
# Epoch 048/50 | train_loss = 0.003803 | val_loss = 0.004852
# Epoch 049/50 | train_loss = 0.003735 | val_loss = 0.004144
# Epoch 050/50 | train_loss = 0.003728 | val_loss = 0.004143
# → Final val_loss = 0.004143
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 0.0001
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.876453 | val_loss = 0.657071
# Epoch 002/5 | train_loss = 0.526421 | val_loss = 0.429163
# Epoch 003/5 | train_loss = 0.369102 | val_loss = 0.321234
# Epoch 004/5 | train_loss = 0.277954 | val_loss = 0.249827
# Epoch 005/5 | train_loss = 0.216588 | val_loss = 0.200014
# → Final val_loss = 0.200014
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 0.0001
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.875556 | val_loss = 0.652428
# Epoch 002/10 | train_loss = 0.524521 | val_loss = 0.428019
# Epoch 003/10 | train_loss = 0.367154 | val_loss = 0.318118
# Epoch 004/10 | train_loss = 0.275108 | val_loss = 0.246641
# Epoch 005/10 | train_loss = 0.213450 | val_loss = 0.196691
# Epoch 006/10 | train_loss = 0.170496 | val_loss = 0.161240
# Epoch 007/10 | train_loss = 0.139843 | val_loss = 0.135683
# Epoch 008/10 | train_loss = 0.117761 | val_loss = 0.116795
# Epoch 009/10 | train_loss = 0.101723 | val_loss = 0.103065
# Epoch 010/10 | train_loss = 0.089760 | val_loss = 0.092574
# → Final val_loss = 0.092574
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 0.0001
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.871386 | val_loss = 0.654659
# Epoch 002/50 | train_loss = 0.527655 | val_loss = 0.434412
# Epoch 003/50 | train_loss = 0.372438 | val_loss = 0.324678
# Epoch 004/50 | train_loss = 0.280298 | val_loss = 0.253135
# Epoch 005/50 | train_loss = 0.219091 | val_loss = 0.202992
# Epoch 006/50 | train_loss = 0.175954 | val_loss = 0.166738
# Epoch 007/50 | train_loss = 0.144581 | val_loss = 0.139812
# Epoch 008/50 | train_loss = 0.121449 | val_loss = 0.119850
# Epoch 009/50 | train_loss = 0.104654 | val_loss = 0.105367
# Epoch 010/50 | train_loss = 0.092232 | val_loss = 0.094502
# Epoch 011/50 | train_loss = 0.082721 | val_loss = 0.085726
# Epoch 012/50 | train_loss = 0.074946 | val_loss = 0.078573
# Epoch 013/50 | train_loss = 0.068520 | val_loss = 0.072585
# Epoch 014/50 | train_loss = 0.063066 | val_loss = 0.067237
# Epoch 015/50 | train_loss = 0.058361 | val_loss = 0.062618
# Epoch 016/50 | train_loss = 0.054253 | val_loss = 0.058684
# Epoch 017/50 | train_loss = 0.050679 | val_loss = 0.055121
# Epoch 018/50 | train_loss = 0.047506 | val_loss = 0.051998
# Epoch 019/50 | train_loss = 0.044724 | val_loss = 0.049097
# Epoch 020/50 | train_loss = 0.042206 | val_loss = 0.046552
# Epoch 021/50 | train_loss = 0.039971 | val_loss = 0.044206
# Epoch 022/50 | train_loss = 0.037948 | val_loss = 0.042302
# Epoch 023/50 | train_loss = 0.036112 | val_loss = 0.040225
# Epoch 024/50 | train_loss = 0.034414 | val_loss = 0.038455
# Epoch 025/50 | train_loss = 0.032901 | val_loss = 0.036827
# Epoch 026/50 | train_loss = 0.031461 | val_loss = 0.035389
# Epoch 027/50 | train_loss = 0.030165 | val_loss = 0.034014
# Epoch 028/50 | train_loss = 0.028968 | val_loss = 0.032721
# Epoch 029/50 | train_loss = 0.027862 | val_loss = 0.031611
# Epoch 030/50 | train_loss = 0.026805 | val_loss = 0.030370
# Epoch 031/50 | train_loss = 0.025840 | val_loss = 0.029347
# Epoch 032/50 | train_loss = 0.024954 | val_loss = 0.028362
# Epoch 033/50 | train_loss = 0.024104 | val_loss = 0.027460
# Epoch 034/50 | train_loss = 0.023295 | val_loss = 0.026599
# Epoch 035/50 | train_loss = 0.022552 | val_loss = 0.025789
# Epoch 036/50 | train_loss = 0.021853 | val_loss = 0.025142
# Epoch 037/50 | train_loss = 0.021203 | val_loss = 0.024267
# Epoch 038/50 | train_loss = 0.020584 | val_loss = 0.023613
# Epoch 039/50 | train_loss = 0.019989 | val_loss = 0.022928
# Epoch 040/50 | train_loss = 0.019456 | val_loss = 0.022376
# Epoch 041/50 | train_loss = 0.018893 | val_loss = 0.021791
# Epoch 042/50 | train_loss = 0.018406 | val_loss = 0.021179
# Epoch 043/50 | train_loss = 0.017927 | val_loss = 0.020699
# Epoch 044/50 | train_loss = 0.017458 | val_loss = 0.020210
# Epoch 045/50 | train_loss = 0.017008 | val_loss = 0.019704
# Epoch 046/50 | train_loss = 0.016611 | val_loss = 0.019183
# Epoch 047/50 | train_loss = 0.016192 | val_loss = 0.018716
# Epoch 048/50 | train_loss = 0.015806 | val_loss = 0.018329
# Epoch 049/50 | train_loss = 0.015442 | val_loss = 0.017935
# Epoch 050/50 | train_loss = 0.015087 | val_loss = 0.017504
# → Final val_loss = 0.017504
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 1e-05
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.998588 | val_loss = 0.987083
# Epoch 002/5 | train_loss = 0.982890 | val_loss = 0.968478
# Epoch 003/5 | train_loss = 0.960222 | val_loss = 0.940598
# Epoch 004/5 | train_loss = 0.927145 | val_loss = 0.901097
# Epoch 005/5 | train_loss = 0.883059 | val_loss = 0.851337
# → Final val_loss = 0.851337
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 1e-05
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 1.001794 | val_loss = 0.991003
# Epoch 002/10 | train_loss = 0.988115 | val_loss = 0.975014
# Epoch 003/10 | train_loss = 0.967962 | val_loss = 0.949593
# Epoch 004/10 | train_loss = 0.936293 | val_loss = 0.910753
# Epoch 005/10 | train_loss = 0.891246 | val_loss = 0.859356
# Epoch 006/10 | train_loss = 0.836450 | val_loss = 0.801447
# Epoch 007/10 | train_loss = 0.778874 | val_loss = 0.744422
# Epoch 008/10 | train_loss = 0.724572 | val_loss = 0.693267
# Epoch 009/10 | train_loss = 0.676899 | val_loss = 0.649940
# Epoch 010/10 | train_loss = 0.636463 | val_loss = 0.613582
# → Final val_loss = 0.613582
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 1e-05
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.998988 | val_loss = 0.987088
# Epoch 002/50 | train_loss = 0.983289 | val_loss = 0.968460
# Epoch 003/50 | train_loss = 0.960023 | val_loss = 0.939561
# Epoch 004/50 | train_loss = 0.924787 | val_loss = 0.897410
# Epoch 005/50 | train_loss = 0.877161 | val_loss = 0.844372
# Epoch 006/50 | train_loss = 0.821201 | val_loss = 0.785990
# Epoch 007/50 | train_loss = 0.763530 | val_loss = 0.729960
# Epoch 008/50 | train_loss = 0.710726 | val_loss = 0.681468
# Epoch 009/50 | train_loss = 0.665732 | val_loss = 0.641084
# Epoch 010/50 | train_loss = 0.628105 | val_loss = 0.607195
# Epoch 011/50 | train_loss = 0.595810 | val_loss = 0.577983
# Epoch 012/50 | train_loss = 0.567826 | val_loss = 0.552379
# Epoch 013/50 | train_loss = 0.542968 | val_loss = 0.529709
# Epoch 014/50 | train_loss = 0.520815 | val_loss = 0.509443
# Epoch 015/50 | train_loss = 0.500835 | val_loss = 0.491231
# Epoch 016/50 | train_loss = 0.482654 | val_loss = 0.474464
# Epoch 017/50 | train_loss = 0.465847 | val_loss = 0.458882
# Epoch 018/50 | train_loss = 0.450151 | val_loss = 0.444310
# Epoch 019/50 | train_loss = 0.435348 | val_loss = 0.430552
# Epoch 020/50 | train_loss = 0.421416 | val_loss = 0.417515
# Epoch 021/50 | train_loss = 0.408177 | val_loss = 0.405077
# Epoch 022/50 | train_loss = 0.395463 | val_loss = 0.393105
# Epoch 023/50 | train_loss = 0.383401 | val_loss = 0.381701
# Epoch 024/50 | train_loss = 0.371828 | val_loss = 0.370808
# Epoch 025/50 | train_loss = 0.360681 | val_loss = 0.360320
# Epoch 026/50 | train_loss = 0.350063 | val_loss = 0.350213
# Epoch 027/50 | train_loss = 0.339779 | val_loss = 0.340533
# Epoch 028/50 | train_loss = 0.329966 | val_loss = 0.331225
# Epoch 029/50 | train_loss = 0.320497 | val_loss = 0.322222
# Epoch 030/50 | train_loss = 0.311414 | val_loss = 0.313552
# Epoch 031/50 | train_loss = 0.302659 | val_loss = 0.305260
# Epoch 032/50 | train_loss = 0.294238 | val_loss = 0.297247
# Epoch 033/50 | train_loss = 0.286199 | val_loss = 0.289537
# Epoch 034/50 | train_loss = 0.278434 | val_loss = 0.282085
# Epoch 035/50 | train_loss = 0.270949 | val_loss = 0.274977
# Epoch 036/50 | train_loss = 0.263754 | val_loss = 0.268084
# Epoch 037/50 | train_loss = 0.256850 | val_loss = 0.261473
# Epoch 038/50 | train_loss = 0.250197 | val_loss = 0.255090
# Epoch 039/50 | train_loss = 0.243811 | val_loss = 0.248933
# Epoch 040/50 | train_loss = 0.237609 | val_loss = 0.242978
# Epoch 041/50 | train_loss = 0.231657 | val_loss = 0.237271
# Epoch 042/50 | train_loss = 0.225919 | val_loss = 0.231722
# Epoch 043/50 | train_loss = 0.220399 | val_loss = 0.226357
# Epoch 044/50 | train_loss = 0.215049 | val_loss = 0.221189
# Epoch 045/50 | train_loss = 0.209895 | val_loss = 0.216237
# Epoch 046/50 | train_loss = 0.204923 | val_loss = 0.211356
# Epoch 047/50 | train_loss = 0.200092 | val_loss = 0.206645
# Epoch 048/50 | train_loss = 0.195415 | val_loss = 0.202181
# Epoch 049/50 | train_loss = 0.190927 | val_loss = 0.197704
# Epoch 050/50 | train_loss = 0.186557 | val_loss = 0.193466
# → Final val_loss = 0.193466
#
# ============================================================
# 🏆 BEST MODEL FOUND
#    batch_size = 128
#    lr         = 0.001
#    epochs     = 50
#    best val_loss = 0.003888
#    Saved as: MLP_BEST.pt
# ============================================================

# %%
# =============================================================================
print('\n⏳ Step 3.2: CNN...')

class CircularConv1d(nn.Module):
    """Conv1D con padding circolare (periodico) per sistemi come L96."""
    def __init__(self, in_channels, out_channels, kernel_size):
        super().__init__()
        pad = (kernel_size - 1) // 2  # padding simmetrico
        self.conv = nn.Conv1d(
            in_channels,
            out_channels,
            kernel_size,
            padding=pad,
            padding_mode="circular"
        )

    def forward(self, x):
        # x: (batch, time, features)
        x = x.transpose(1, 2)  # → (batch, features, time)
        x = self.conv(x)
        return x.transpose(1, 2)  # → (batch, time, channels)


class CNN(nn.Module):
    def __init__(self, n_features, window):
        super().__init__()

        self.conv1 = CircularConv1d(n_features, 64, kernel_size=3)
        self.conv2 = CircularConv1d(64, 64, kernel_size=3)

        self.flatten = nn.Flatten()

        self.fc1 = nn.Linear(window * 64, 128)
        self.fc2 = nn.Linear(128, n_features)

    def forward(self, x):
        # x: (batch, window, n_features)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))

        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        return self.fc2(x)



# =============================================================================
# ⏳ PIPELINE EXECUTION LOOP
# =============================================================================
model_builder = lambda: CNN(n_features=L96_N, window=WINDOW)
print('\n🏗️  Training CNN...')
cnn, cnn_params, cnn_loss = train_and_search(
    model_builder,
    X96_win_tr, Y96_tr,
    X96_win_vl, Y96_vl,
    name="CNN"
)
# Out:
# ⏳ Step 3.2: CNN...
#
# 🏗️  Training CNN...
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 0.001
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.355751 | val_loss = 0.213953
# Epoch 002/5 | train_loss = 0.154106 | val_loss = 0.126870
# Epoch 003/5 | train_loss = 0.096825 | val_loss = 0.082986
# Epoch 004/5 | train_loss = 0.067057 | val_loss = 0.061289
# Epoch 005/5 | train_loss = 0.051029 | val_loss = 0.046883
# → Final val_loss = 0.046883
# ⭐ New best model found!
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 0.001
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.353462 | val_loss = 0.205779
# Epoch 002/10 | train_loss = 0.153418 | val_loss = 0.121512
# Epoch 003/10 | train_loss = 0.096460 | val_loss = 0.087028
# Epoch 004/10 | train_loss = 0.066780 | val_loss = 0.060086
# Epoch 005/10 | train_loss = 0.049865 | val_loss = 0.045870
# Epoch 006/10 | train_loss = 0.040698 | val_loss = 0.042181
# Epoch 007/10 | train_loss = 0.035017 | val_loss = 0.033880
# Epoch 008/10 | train_loss = 0.030772 | val_loss = 0.031160
# Epoch 009/10 | train_loss = 0.027893 | val_loss = 0.026219
# Epoch 010/10 | train_loss = 0.025888 | val_loss = 0.027306
# → Final val_loss = 0.027306
# ⭐ New best model found!
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 0.001
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.352903 | val_loss = 0.204034
# Epoch 002/50 | train_loss = 0.152785 | val_loss = 0.120676
# Epoch 003/50 | train_loss = 0.095374 | val_loss = 0.079938
# Epoch 004/50 | train_loss = 0.065900 | val_loss = 0.062001
# Epoch 005/50 | train_loss = 0.049854 | val_loss = 0.046792
# Epoch 006/50 | train_loss = 0.040754 | val_loss = 0.039735
# Epoch 007/50 | train_loss = 0.034850 | val_loss = 0.038006
# Epoch 008/50 | train_loss = 0.030936 | val_loss = 0.031614
# Epoch 009/50 | train_loss = 0.028126 | val_loss = 0.029714
# Epoch 010/50 | train_loss = 0.026118 | val_loss = 0.026245
# Epoch 011/50 | train_loss = 0.024207 | val_loss = 0.026235
# Epoch 012/50 | train_loss = 0.022898 | val_loss = 0.025079
# Epoch 013/50 | train_loss = 0.021548 | val_loss = 0.023508
# Epoch 014/50 | train_loss = 0.020502 | val_loss = 0.020455
# Epoch 015/50 | train_loss = 0.019565 | val_loss = 0.019922
# Epoch 016/50 | train_loss = 0.018866 | val_loss = 0.019976
# Epoch 017/50 | train_loss = 0.018016 | val_loss = 0.017376
# Epoch 018/50 | train_loss = 0.017280 | val_loss = 0.019420
# Epoch 019/50 | train_loss = 0.016842 | val_loss = 0.016239
# Epoch 020/50 | train_loss = 0.016125 | val_loss = 0.017868
# Epoch 021/50 | train_loss = 0.015751 | val_loss = 0.016855
# Epoch 022/50 | train_loss = 0.015265 | val_loss = 0.020220
# Epoch 023/50 | train_loss = 0.014770 | val_loss = 0.016220
# Epoch 024/50 | train_loss = 0.014558 | val_loss = 0.014973
# Epoch 025/50 | train_loss = 0.014058 | val_loss = 0.014563
# Epoch 026/50 | train_loss = 0.013862 | val_loss = 0.014170
# Epoch 027/50 | train_loss = 0.013536 | val_loss = 0.014029
# Epoch 028/50 | train_loss = 0.013183 | val_loss = 0.013951
# Epoch 029/50 | train_loss = 0.012980 | val_loss = 0.012794
# Epoch 030/50 | train_loss = 0.012927 | val_loss = 0.015957
# Epoch 031/50 | train_loss = 0.012522 | val_loss = 0.012623
# Epoch 032/50 | train_loss = 0.012252 | val_loss = 0.012638
# Epoch 033/50 | train_loss = 0.012108 | val_loss = 0.013742
# Epoch 034/50 | train_loss = 0.011944 | val_loss = 0.011768
# Epoch 035/50 | train_loss = 0.011620 | val_loss = 0.011760
# Epoch 036/50 | train_loss = 0.011691 | val_loss = 0.012016
# Epoch 037/50 | train_loss = 0.011469 | val_loss = 0.010801
# Epoch 038/50 | train_loss = 0.011397 | val_loss = 0.010199
# Epoch 039/50 | train_loss = 0.011228 | val_loss = 0.011251
# Epoch 040/50 | train_loss = 0.011184 | val_loss = 0.012092
# Epoch 041/50 | train_loss = 0.010694 | val_loss = 0.011044
# Epoch 042/50 | train_loss = 0.010821 | val_loss = 0.014137
# Epoch 043/50 | train_loss = 0.010773 | val_loss = 0.012722
# Epoch 044/50 | train_loss = 0.010450 | val_loss = 0.013147
# Epoch 045/50 | train_loss = 0.010510 | val_loss = 0.010777
# Epoch 046/50 | train_loss = 0.010241 | val_loss = 0.012590
# Epoch 047/50 | train_loss = 0.010058 | val_loss = 0.013552
# Epoch 048/50 | train_loss = 0.010210 | val_loss = 0.010351
# Epoch 049/50 | train_loss = 0.010018 | val_loss = 0.011057
# Epoch 050/50 | train_loss = 0.010081 | val_loss = 0.011070
# → Final val_loss = 0.011070
# ⭐ New best model found!
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 0.0001
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.663695 | val_loss = 0.457267
# Epoch 002/5 | train_loss = 0.395872 | val_loss = 0.351151
# Epoch 003/5 | train_loss = 0.316849 | val_loss = 0.295777
# Epoch 004/5 | train_loss = 0.270199 | val_loss = 0.258475
# Epoch 005/5 | train_loss = 0.237576 | val_loss = 0.230539
# → Final val_loss = 0.230539
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 0.0001
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.662523 | val_loss = 0.462208
# Epoch 002/10 | train_loss = 0.397432 | val_loss = 0.350679
# Epoch 003/10 | train_loss = 0.316227 | val_loss = 0.292940
# Epoch 004/10 | train_loss = 0.268137 | val_loss = 0.254210
# Epoch 005/10 | train_loss = 0.234250 | val_loss = 0.226100
# Epoch 006/10 | train_loss = 0.208278 | val_loss = 0.202088
# Epoch 007/10 | train_loss = 0.187010 | val_loss = 0.183759
# Epoch 008/10 | train_loss = 0.169277 | val_loss = 0.166847
# Epoch 009/10 | train_loss = 0.154143 | val_loss = 0.152588
# Epoch 010/10 | train_loss = 0.141160 | val_loss = 0.139965
# → Final val_loss = 0.139965
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 0.0001
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.661231 | val_loss = 0.463800
# Epoch 002/50 | train_loss = 0.401008 | val_loss = 0.353761
# Epoch 003/50 | train_loss = 0.320904 | val_loss = 0.296187
# Epoch 004/50 | train_loss = 0.273581 | val_loss = 0.259800
# Epoch 005/50 | train_loss = 0.240797 | val_loss = 0.232242
# Epoch 006/50 | train_loss = 0.215628 | val_loss = 0.210093
# Epoch 007/50 | train_loss = 0.195185 | val_loss = 0.192155
# Epoch 008/50 | train_loss = 0.177765 | val_loss = 0.175721
# Epoch 009/50 | train_loss = 0.162763 | val_loss = 0.161754
# Epoch 010/50 | train_loss = 0.149691 | val_loss = 0.148897
# Epoch 011/50 | train_loss = 0.138146 | val_loss = 0.139376
# Epoch 012/50 | train_loss = 0.127761 | val_loss = 0.128490
# Epoch 013/50 | train_loss = 0.118471 | val_loss = 0.118847
# Epoch 014/50 | train_loss = 0.109991 | val_loss = 0.110408
# Epoch 015/50 | train_loss = 0.102503 | val_loss = 0.104069
# Epoch 016/50 | train_loss = 0.095825 | val_loss = 0.097560
# Epoch 017/50 | train_loss = 0.089384 | val_loss = 0.090508
# Epoch 018/50 | train_loss = 0.083832 | val_loss = 0.084833
# Epoch 019/50 | train_loss = 0.078400 | val_loss = 0.078978
# Epoch 020/50 | train_loss = 0.073510 | val_loss = 0.074443
# Epoch 021/50 | train_loss = 0.069000 | val_loss = 0.069664
# Epoch 022/50 | train_loss = 0.064703 | val_loss = 0.065745
# Epoch 023/50 | train_loss = 0.061037 | val_loss = 0.061634
# Epoch 024/50 | train_loss = 0.057554 | val_loss = 0.058780
# Epoch 025/50 | train_loss = 0.054271 | val_loss = 0.055435
# Epoch 026/50 | train_loss = 0.051353 | val_loss = 0.051959
# Epoch 027/50 | train_loss = 0.048683 | val_loss = 0.050147
# Epoch 028/50 | train_loss = 0.046160 | val_loss = 0.047053
# Epoch 029/50 | train_loss = 0.043920 | val_loss = 0.044750
# Epoch 030/50 | train_loss = 0.041844 | val_loss = 0.042590
# Epoch 031/50 | train_loss = 0.039976 | val_loss = 0.040796
# Epoch 032/50 | train_loss = 0.038200 | val_loss = 0.039343
# Epoch 033/50 | train_loss = 0.036606 | val_loss = 0.037643
# Epoch 034/50 | train_loss = 0.035144 | val_loss = 0.036602
# Epoch 035/50 | train_loss = 0.033794 | val_loss = 0.034561
# Epoch 036/50 | train_loss = 0.032524 | val_loss = 0.033392
# Epoch 037/50 | train_loss = 0.031341 | val_loss = 0.032671
# Epoch 038/50 | train_loss = 0.030316 | val_loss = 0.030960
# Epoch 039/50 | train_loss = 0.029228 | val_loss = 0.030178
# Epoch 040/50 | train_loss = 0.028286 | val_loss = 0.029512
# Epoch 041/50 | train_loss = 0.027506 | val_loss = 0.028002
# Epoch 042/50 | train_loss = 0.026631 | val_loss = 0.027265
# Epoch 043/50 | train_loss = 0.025843 | val_loss = 0.026460
# Epoch 044/50 | train_loss = 0.025149 | val_loss = 0.025685
# Epoch 045/50 | train_loss = 0.024472 | val_loss = 0.025280
# Epoch 046/50 | train_loss = 0.023858 | val_loss = 0.024655
# Epoch 047/50 | train_loss = 0.023259 | val_loss = 0.024104
# Epoch 048/50 | train_loss = 0.022659 | val_loss = 0.023550
# Epoch 049/50 | train_loss = 0.022156 | val_loss = 0.022826
# Epoch 050/50 | train_loss = 0.021642 | val_loss = 0.022135
# → Final val_loss = 0.022135
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 1e-05
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.983660 | val_loss = 0.947047
# Epoch 002/5 | train_loss = 0.889110 | val_loss = 0.812885
# Epoch 003/5 | train_loss = 0.755037 | val_loss = 0.696171
# Epoch 004/5 | train_loss = 0.664473 | val_loss = 0.630383
# Epoch 005/5 | train_loss = 0.609922 | val_loss = 0.585768
# → Final val_loss = 0.585768
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 1e-05
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.982669 | val_loss = 0.944822
# Epoch 002/10 | train_loss = 0.889385 | val_loss = 0.817999
# Epoch 003/10 | train_loss = 0.765907 | val_loss = 0.708578
# Epoch 004/10 | train_loss = 0.675944 | val_loss = 0.637937
# Epoch 005/10 | train_loss = 0.616277 | val_loss = 0.589535
# Epoch 006/10 | train_loss = 0.572915 | val_loss = 0.553012
# Epoch 007/10 | train_loss = 0.539108 | val_loss = 0.524080
# Epoch 008/10 | train_loss = 0.512053 | val_loss = 0.500386
# Epoch 009/10 | train_loss = 0.489505 | val_loss = 0.480151
# Epoch 010/10 | train_loss = 0.470003 | val_loss = 0.462374
# → Final val_loss = 0.462374
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 128
#    lr         = 1e-05
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.983784 | val_loss = 0.948355
# Epoch 002/50 | train_loss = 0.890048 | val_loss = 0.814541
# Epoch 003/50 | train_loss = 0.754550 | val_loss = 0.696565
# Epoch 004/50 | train_loss = 0.662391 | val_loss = 0.626485
# Epoch 005/50 | train_loss = 0.605406 | val_loss = 0.580776
# Epoch 006/50 | train_loss = 0.565566 | val_loss = 0.546467
# Epoch 007/50 | train_loss = 0.534545 | val_loss = 0.519077
# Epoch 008/50 | train_loss = 0.508609 | val_loss = 0.495442
# Epoch 009/50 | train_loss = 0.486242 | val_loss = 0.475311
# Epoch 010/50 | train_loss = 0.466671 | val_loss = 0.457410
# Epoch 011/50 | train_loss = 0.449311 | val_loss = 0.441449
# Epoch 012/50 | train_loss = 0.433741 | val_loss = 0.427021
# Epoch 013/50 | train_loss = 0.419617 | val_loss = 0.414078
# Epoch 014/50 | train_loss = 0.406770 | val_loss = 0.402350
# Epoch 015/50 | train_loss = 0.394948 | val_loss = 0.391135
# Epoch 016/50 | train_loss = 0.384040 | val_loss = 0.381082
# Epoch 017/50 | train_loss = 0.373926 | val_loss = 0.371740
# Epoch 018/50 | train_loss = 0.364486 | val_loss = 0.362836
# Epoch 019/50 | train_loss = 0.355573 | val_loss = 0.354491
# Epoch 020/50 | train_loss = 0.347212 | val_loss = 0.346673
# Epoch 021/50 | train_loss = 0.339367 | val_loss = 0.339350
# Epoch 022/50 | train_loss = 0.331989 | val_loss = 0.332437
# Epoch 023/50 | train_loss = 0.324998 | val_loss = 0.325745
# Epoch 024/50 | train_loss = 0.318381 | val_loss = 0.319567
# Epoch 025/50 | train_loss = 0.312116 | val_loss = 0.313653
# Epoch 026/50 | train_loss = 0.306138 | val_loss = 0.307925
# Epoch 027/50 | train_loss = 0.300382 | val_loss = 0.302736
# Epoch 028/50 | train_loss = 0.294965 | val_loss = 0.297354
# Epoch 029/50 | train_loss = 0.289778 | val_loss = 0.292510
# Epoch 030/50 | train_loss = 0.284775 | val_loss = 0.287741
# Epoch 031/50 | train_loss = 0.279971 | val_loss = 0.283105
# Epoch 032/50 | train_loss = 0.275409 | val_loss = 0.278619
# Epoch 033/50 | train_loss = 0.270975 | val_loss = 0.274494
# Epoch 034/50 | train_loss = 0.266695 | val_loss = 0.270240
# Epoch 035/50 | train_loss = 0.262570 | val_loss = 0.266236
# Epoch 036/50 | train_loss = 0.258620 | val_loss = 0.262465
# Epoch 037/50 | train_loss = 0.254776 | val_loss = 0.258642
# Epoch 038/50 | train_loss = 0.251010 | val_loss = 0.255071
# Epoch 039/50 | train_loss = 0.247413 | val_loss = 0.251684
# Epoch 040/50 | train_loss = 0.243903 | val_loss = 0.248024
# Epoch 041/50 | train_loss = 0.240511 | val_loss = 0.244737
# Epoch 042/50 | train_loss = 0.237173 | val_loss = 0.241575
# Epoch 043/50 | train_loss = 0.233986 | val_loss = 0.238435
# Epoch 044/50 | train_loss = 0.230800 | val_loss = 0.235270
# Epoch 045/50 | train_loss = 0.227753 | val_loss = 0.232202
# Epoch 046/50 | train_loss = 0.224755 | val_loss = 0.229323
# Epoch 047/50 | train_loss = 0.221876 | val_loss = 0.226409
# Epoch 048/50 | train_loss = 0.218988 | val_loss = 0.223517
# Epoch 049/50 | train_loss = 0.216222 | val_loss = 0.220746
# Epoch 050/50 | train_loss = 0.213482 | val_loss = 0.218009
# → Final val_loss = 0.218009
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 0.001
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.430862 | val_loss = 0.268624
# Epoch 002/5 | train_loss = 0.212116 | val_loss = 0.183716
# Epoch 003/5 | train_loss = 0.146225 | val_loss = 0.130945
# Epoch 004/5 | train_loss = 0.108533 | val_loss = 0.101846
# Epoch 005/5 | train_loss = 0.085225 | val_loss = 0.080237
# → Final val_loss = 0.080237
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 0.001
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.433901 | val_loss = 0.276629
# Epoch 002/10 | train_loss = 0.215667 | val_loss = 0.187446
# Epoch 003/10 | train_loss = 0.152083 | val_loss = 0.138861
# Epoch 004/10 | train_loss = 0.114139 | val_loss = 0.107299
# Epoch 005/10 | train_loss = 0.089078 | val_loss = 0.085685
# Epoch 006/10 | train_loss = 0.071965 | val_loss = 0.069846
# Epoch 007/10 | train_loss = 0.059563 | val_loss = 0.058402
# Epoch 008/10 | train_loss = 0.051016 | val_loss = 0.051402
# Epoch 009/10 | train_loss = 0.044493 | val_loss = 0.044253
# Epoch 010/10 | train_loss = 0.039965 | val_loss = 0.042669
# → Final val_loss = 0.042669
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 0.001
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.435766 | val_loss = 0.275440
# Epoch 002/50 | train_loss = 0.218420 | val_loss = 0.186624
# Epoch 003/50 | train_loss = 0.152444 | val_loss = 0.139547
# Epoch 004/50 | train_loss = 0.114162 | val_loss = 0.107147
# Epoch 005/50 | train_loss = 0.089360 | val_loss = 0.082490
# Epoch 006/50 | train_loss = 0.071835 | val_loss = 0.067884
# Epoch 007/50 | train_loss = 0.059770 | val_loss = 0.061067
# Epoch 008/50 | train_loss = 0.050796 | val_loss = 0.050646
# Epoch 009/50 | train_loss = 0.043854 | val_loss = 0.044422
# Epoch 010/50 | train_loss = 0.039073 | val_loss = 0.040552
# Epoch 011/50 | train_loss = 0.035438 | val_loss = 0.037704
# Epoch 012/50 | train_loss = 0.032680 | val_loss = 0.033771
# Epoch 013/50 | train_loss = 0.030118 | val_loss = 0.034465
# Epoch 014/50 | train_loss = 0.028310 | val_loss = 0.029989
# Epoch 015/50 | train_loss = 0.026717 | val_loss = 0.028116
# Epoch 016/50 | train_loss = 0.025717 | val_loss = 0.026864
# Epoch 017/50 | train_loss = 0.024074 | val_loss = 0.026026
# Epoch 018/50 | train_loss = 0.023314 | val_loss = 0.026588
# Epoch 019/50 | train_loss = 0.022385 | val_loss = 0.023471
# Epoch 020/50 | train_loss = 0.021166 | val_loss = 0.022839
# Epoch 021/50 | train_loss = 0.020641 | val_loss = 0.024925
# Epoch 022/50 | train_loss = 0.020203 | val_loss = 0.022505
# Epoch 023/50 | train_loss = 0.019281 | val_loss = 0.021417
# Epoch 024/50 | train_loss = 0.018741 | val_loss = 0.019897
# Epoch 025/50 | train_loss = 0.018383 | val_loss = 0.019079
# Epoch 026/50 | train_loss = 0.018155 | val_loss = 0.019764
# Epoch 027/50 | train_loss = 0.017223 | val_loss = 0.017883
# Epoch 028/50 | train_loss = 0.016824 | val_loss = 0.017682
# Epoch 029/50 | train_loss = 0.016441 | val_loss = 0.018385
# Epoch 030/50 | train_loss = 0.016506 | val_loss = 0.018165
# Epoch 031/50 | train_loss = 0.015623 | val_loss = 0.018216
# Epoch 032/50 | train_loss = 0.015487 | val_loss = 0.017094
# Epoch 033/50 | train_loss = 0.015255 | val_loss = 0.016551
# Epoch 034/50 | train_loss = 0.014970 | val_loss = 0.014092
# Epoch 035/50 | train_loss = 0.014674 | val_loss = 0.018077
# Epoch 036/50 | train_loss = 0.014375 | val_loss = 0.017187
# Epoch 037/50 | train_loss = 0.014082 | val_loss = 0.015736
# Epoch 038/50 | train_loss = 0.014005 | val_loss = 0.015348
# Epoch 039/50 | train_loss = 0.013507 | val_loss = 0.014454
# Epoch 040/50 | train_loss = 0.013300 | val_loss = 0.016859
# Epoch 041/50 | train_loss = 0.013344 | val_loss = 0.014850
# Epoch 042/50 | train_loss = 0.013020 | val_loss = 0.014489
# Epoch 043/50 | train_loss = 0.012760 | val_loss = 0.014383
# Epoch 044/50 | train_loss = 0.012986 | val_loss = 0.018548
# Epoch 045/50 | train_loss = 0.012626 | val_loss = 0.014076
# Epoch 046/50 | train_loss = 0.012150 | val_loss = 0.015103
# Epoch 047/50 | train_loss = 0.012164 | val_loss = 0.013781
# Epoch 048/50 | train_loss = 0.012193 | val_loss = 0.013106
# Epoch 049/50 | train_loss = 0.011932 | val_loss = 0.014232
# Epoch 050/50 | train_loss = 0.011726 | val_loss = 0.013726
# → Final val_loss = 0.013726
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 0.0001
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.772185 | val_loss = 0.558236
# Epoch 002/5 | train_loss = 0.482798 | val_loss = 0.428426
# Epoch 003/5 | train_loss = 0.390045 | val_loss = 0.363435
# Epoch 004/5 | train_loss = 0.336655 | val_loss = 0.322090
# Epoch 005/5 | train_loss = 0.299578 | val_loss = 0.289974
# → Final val_loss = 0.289974
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 0.0001
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.781006 | val_loss = 0.563681
# Epoch 002/10 | train_loss = 0.489425 | val_loss = 0.430744
# Epoch 003/10 | train_loss = 0.392339 | val_loss = 0.362454
# Epoch 004/10 | train_loss = 0.335676 | val_loss = 0.318452
# Epoch 005/10 | train_loss = 0.297889 | val_loss = 0.287146
# Epoch 006/10 | train_loss = 0.269748 | val_loss = 0.263290
# Epoch 007/10 | train_loss = 0.247722 | val_loss = 0.244451
# Epoch 008/10 | train_loss = 0.229416 | val_loss = 0.227731
# Epoch 009/10 | train_loss = 0.213744 | val_loss = 0.213056
# Epoch 010/10 | train_loss = 0.200266 | val_loss = 0.201452
# → Final val_loss = 0.201452
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 0.0001
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.778491 | val_loss = 0.558040
# Epoch 002/50 | train_loss = 0.481599 | val_loss = 0.424063
# Epoch 003/50 | train_loss = 0.385454 | val_loss = 0.358393
# Epoch 004/50 | train_loss = 0.331148 | val_loss = 0.317335
# Epoch 005/50 | train_loss = 0.294419 | val_loss = 0.287135
# Epoch 006/50 | train_loss = 0.266885 | val_loss = 0.262083
# Epoch 007/50 | train_loss = 0.244986 | val_loss = 0.242633
# Epoch 008/50 | train_loss = 0.227253 | val_loss = 0.226165
# Epoch 009/50 | train_loss = 0.212432 | val_loss = 0.213037
# Epoch 010/50 | train_loss = 0.199373 | val_loss = 0.200718
# Epoch 011/50 | train_loss = 0.188081 | val_loss = 0.189670
# Epoch 012/50 | train_loss = 0.177583 | val_loss = 0.179659
# Epoch 013/50 | train_loss = 0.168122 | val_loss = 0.171282
# Epoch 014/50 | train_loss = 0.159611 | val_loss = 0.161711
# Epoch 015/50 | train_loss = 0.151596 | val_loss = 0.154827
# Epoch 016/50 | train_loss = 0.144397 | val_loss = 0.147790
# Epoch 017/50 | train_loss = 0.137860 | val_loss = 0.140881
# Epoch 018/50 | train_loss = 0.131489 | val_loss = 0.134607
# Epoch 019/50 | train_loss = 0.125675 | val_loss = 0.129854
# Epoch 020/50 | train_loss = 0.120312 | val_loss = 0.123432
# Epoch 021/50 | train_loss = 0.115244 | val_loss = 0.119297
# Epoch 022/50 | train_loss = 0.110686 | val_loss = 0.114322
# Epoch 023/50 | train_loss = 0.106050 | val_loss = 0.109080
# Epoch 024/50 | train_loss = 0.101974 | val_loss = 0.105214
# Epoch 025/50 | train_loss = 0.098008 | val_loss = 0.101652
# Epoch 026/50 | train_loss = 0.094283 | val_loss = 0.097563
# Epoch 027/50 | train_loss = 0.090773 | val_loss = 0.093880
# Epoch 028/50 | train_loss = 0.087346 | val_loss = 0.090321
# Epoch 029/50 | train_loss = 0.084262 | val_loss = 0.087428
# Epoch 030/50 | train_loss = 0.081124 | val_loss = 0.084297
# Epoch 031/50 | train_loss = 0.078180 | val_loss = 0.081379
# Epoch 032/50 | train_loss = 0.075515 | val_loss = 0.078362
# Epoch 033/50 | train_loss = 0.072784 | val_loss = 0.075656
# Epoch 034/50 | train_loss = 0.070125 | val_loss = 0.072923
# Epoch 035/50 | train_loss = 0.067750 | val_loss = 0.070326
# Epoch 036/50 | train_loss = 0.065394 | val_loss = 0.068095
# Epoch 037/50 | train_loss = 0.063071 | val_loss = 0.065799
# Epoch 038/50 | train_loss = 0.061019 | val_loss = 0.063528
# Epoch 039/50 | train_loss = 0.058897 | val_loss = 0.061301
# Epoch 040/50 | train_loss = 0.056918 | val_loss = 0.059085
# Epoch 041/50 | train_loss = 0.055032 | val_loss = 0.057107
# Epoch 042/50 | train_loss = 0.053174 | val_loss = 0.055260
# Epoch 043/50 | train_loss = 0.051430 | val_loss = 0.053536
# Epoch 044/50 | train_loss = 0.049749 | val_loss = 0.051563
# Epoch 045/50 | train_loss = 0.048191 | val_loss = 0.050224
# Epoch 046/50 | train_loss = 0.046672 | val_loss = 0.048954
# Epoch 047/50 | train_loss = 0.045234 | val_loss = 0.046948
# Epoch 048/50 | train_loss = 0.043887 | val_loss = 0.045930
# Epoch 049/50 | train_loss = 0.042482 | val_loss = 0.044370
# Epoch 050/50 | train_loss = 0.041270 | val_loss = 0.043052
# → Final val_loss = 0.043052
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 1e-05
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.994790 | val_loss = 0.979380
# Epoch 002/5 | train_loss = 0.965624 | val_loss = 0.936258
# Epoch 003/5 | train_loss = 0.908161 | val_loss = 0.862448
# Epoch 004/5 | train_loss = 0.829477 | val_loss = 0.780605
# Epoch 005/5 | train_loss = 0.754955 | val_loss = 0.713721
# → Final val_loss = 0.713721
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 1e-05
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.994127 | val_loss = 0.977332
# Epoch 002/10 | train_loss = 0.960218 | val_loss = 0.926742
# Epoch 003/10 | train_loss = 0.894457 | val_loss = 0.846109
# Epoch 004/10 | train_loss = 0.810797 | val_loss = 0.763896
# Epoch 005/10 | train_loss = 0.738625 | val_loss = 0.702436
# Epoch 006/10 | train_loss = 0.685292 | val_loss = 0.657869
# Epoch 007/10 | train_loss = 0.645079 | val_loss = 0.622979
# Epoch 008/10 | train_loss = 0.612308 | val_loss = 0.593525
# Epoch 009/10 | train_loss = 0.583825 | val_loss = 0.568058
# Epoch 010/10 | train_loss = 0.559122 | val_loss = 0.545644
# → Final val_loss = 0.545644
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 256
#    lr         = 1e-05
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.994647 | val_loss = 0.978056
# Epoch 002/50 | train_loss = 0.959942 | val_loss = 0.925139
# Epoch 003/50 | train_loss = 0.891527 | val_loss = 0.843837
# Epoch 004/50 | train_loss = 0.809806 | val_loss = 0.764711
# Epoch 005/50 | train_loss = 0.737628 | val_loss = 0.701034
# Epoch 006/50 | train_loss = 0.681381 | val_loss = 0.652991
# Epoch 007/50 | train_loss = 0.638642 | val_loss = 0.616504
# Epoch 008/50 | train_loss = 0.605499 | val_loss = 0.587676
# Epoch 009/50 | train_loss = 0.578790 | val_loss = 0.564006
# Epoch 010/50 | train_loss = 0.556255 | val_loss = 0.543536
# Epoch 011/50 | train_loss = 0.536502 | val_loss = 0.525784
# Epoch 012/50 | train_loss = 0.519172 | val_loss = 0.509877
# Epoch 013/50 | train_loss = 0.503534 | val_loss = 0.495717
# Epoch 014/50 | train_loss = 0.489492 | val_loss = 0.482784
# Epoch 015/50 | train_loss = 0.476580 | val_loss = 0.470682
# Epoch 016/50 | train_loss = 0.464491 | val_loss = 0.459741
# Epoch 017/50 | train_loss = 0.453311 | val_loss = 0.449318
# Epoch 018/50 | train_loss = 0.442808 | val_loss = 0.439718
# Epoch 019/50 | train_loss = 0.432972 | val_loss = 0.430537
# Epoch 020/50 | train_loss = 0.423634 | val_loss = 0.421875
# Epoch 021/50 | train_loss = 0.414825 | val_loss = 0.413885
# Epoch 022/50 | train_loss = 0.406541 | val_loss = 0.405976
# Epoch 023/50 | train_loss = 0.398696 | val_loss = 0.398607
# Epoch 024/50 | train_loss = 0.391247 | val_loss = 0.391668
# Epoch 025/50 | train_loss = 0.384005 | val_loss = 0.384973
# Epoch 026/50 | train_loss = 0.377149 | val_loss = 0.378568
# Epoch 027/50 | train_loss = 0.370681 | val_loss = 0.372419
# Epoch 028/50 | train_loss = 0.364437 | val_loss = 0.366602
# Epoch 029/50 | train_loss = 0.358447 | val_loss = 0.360862
# Epoch 030/50 | train_loss = 0.352717 | val_loss = 0.355540
# Epoch 031/50 | train_loss = 0.347144 | val_loss = 0.350232
# Epoch 032/50 | train_loss = 0.341917 | val_loss = 0.345260
# Epoch 033/50 | train_loss = 0.336799 | val_loss = 0.340400
# Epoch 034/50 | train_loss = 0.331866 | val_loss = 0.335721
# Epoch 035/50 | train_loss = 0.327053 | val_loss = 0.331246
# Epoch 036/50 | train_loss = 0.322465 | val_loss = 0.326694
# Epoch 037/50 | train_loss = 0.318043 | val_loss = 0.322608
# Epoch 038/50 | train_loss = 0.313802 | val_loss = 0.318438
# Epoch 039/50 | train_loss = 0.309646 | val_loss = 0.314422
# Epoch 040/50 | train_loss = 0.305608 | val_loss = 0.310655
# Epoch 041/50 | train_loss = 0.301628 | val_loss = 0.306935
# Epoch 042/50 | train_loss = 0.297834 | val_loss = 0.303144
# Epoch 043/50 | train_loss = 0.294218 | val_loss = 0.299737
# Epoch 044/50 | train_loss = 0.290605 | val_loss = 0.296220
# Epoch 045/50 | train_loss = 0.287239 | val_loss = 0.292848
# Epoch 046/50 | train_loss = 0.283750 | val_loss = 0.289622
# Epoch 047/50 | train_loss = 0.280534 | val_loss = 0.286460
# Epoch 048/50 | train_loss = 0.277356 | val_loss = 0.283348
# Epoch 049/50 | train_loss = 0.274213 | val_loss = 0.280241
# Epoch 050/50 | train_loss = 0.271245 | val_loss = 0.277341
# → Final val_loss = 0.277341
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 0.001
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.530754 | val_loss = 0.341734
# Epoch 002/5 | train_loss = 0.283336 | val_loss = 0.248437
# Epoch 003/5 | train_loss = 0.214714 | val_loss = 0.198342
# Epoch 004/5 | train_loss = 0.171790 | val_loss = 0.162747
# Epoch 005/5 | train_loss = 0.143403 | val_loss = 0.138486
# → Final val_loss = 0.138486
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 0.001
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.539277 | val_loss = 0.355164
# Epoch 002/10 | train_loss = 0.290117 | val_loss = 0.250198
# Epoch 003/10 | train_loss = 0.216172 | val_loss = 0.200576
# Epoch 004/10 | train_loss = 0.172968 | val_loss = 0.163371
# Epoch 005/10 | train_loss = 0.144125 | val_loss = 0.138517
# Epoch 006/10 | train_loss = 0.122099 | val_loss = 0.118556
# Epoch 007/10 | train_loss = 0.103970 | val_loss = 0.102695
# Epoch 008/10 | train_loss = 0.090358 | val_loss = 0.088646
# Epoch 009/10 | train_loss = 0.079140 | val_loss = 0.078165
# Epoch 010/10 | train_loss = 0.070026 | val_loss = 0.068711
# → Final val_loss = 0.068711
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 0.001
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.537064 | val_loss = 0.349357
# Epoch 002/50 | train_loss = 0.285450 | val_loss = 0.247464
# Epoch 003/50 | train_loss = 0.213048 | val_loss = 0.196905
# Epoch 004/50 | train_loss = 0.170120 | val_loss = 0.159232
# Epoch 005/50 | train_loss = 0.140280 | val_loss = 0.136774
# Epoch 006/50 | train_loss = 0.118126 | val_loss = 0.113431
# Epoch 007/50 | train_loss = 0.102069 | val_loss = 0.098025
# Epoch 008/50 | train_loss = 0.088759 | val_loss = 0.089897
# Epoch 009/50 | train_loss = 0.078349 | val_loss = 0.080272
# Epoch 010/50 | train_loss = 0.069725 | val_loss = 0.068653
# Epoch 011/50 | train_loss = 0.062197 | val_loss = 0.063353
# Epoch 012/50 | train_loss = 0.057148 | val_loss = 0.055623
# Epoch 013/50 | train_loss = 0.051651 | val_loss = 0.052289
# Epoch 014/50 | train_loss = 0.047515 | val_loss = 0.049966
# Epoch 015/50 | train_loss = 0.044025 | val_loss = 0.043981
# Epoch 016/50 | train_loss = 0.040773 | val_loss = 0.043248
# Epoch 017/50 | train_loss = 0.037871 | val_loss = 0.038992
# Epoch 018/50 | train_loss = 0.036613 | val_loss = 0.037217
# Epoch 019/50 | train_loss = 0.034500 | val_loss = 0.033526
# Epoch 020/50 | train_loss = 0.032451 | val_loss = 0.034702
# Epoch 021/50 | train_loss = 0.031202 | val_loss = 0.033669
# Epoch 022/50 | train_loss = 0.029856 | val_loss = 0.033178
# Epoch 023/50 | train_loss = 0.028795 | val_loss = 0.029093
# Epoch 024/50 | train_loss = 0.027657 | val_loss = 0.027144
# Epoch 025/50 | train_loss = 0.026907 | val_loss = 0.028341
# Epoch 026/50 | train_loss = 0.025696 | val_loss = 0.026874
# Epoch 027/50 | train_loss = 0.024748 | val_loss = 0.025295
# Epoch 028/50 | train_loss = 0.024468 | val_loss = 0.024585
# Epoch 029/50 | train_loss = 0.023835 | val_loss = 0.024537
# Epoch 030/50 | train_loss = 0.023213 | val_loss = 0.023286
# Epoch 031/50 | train_loss = 0.022409 | val_loss = 0.022710
# Epoch 032/50 | train_loss = 0.022095 | val_loss = 0.022936
# Epoch 033/50 | train_loss = 0.021191 | val_loss = 0.021884
# Epoch 034/50 | train_loss = 0.021313 | val_loss = 0.021461
# Epoch 035/50 | train_loss = 0.020341 | val_loss = 0.020253
# Epoch 036/50 | train_loss = 0.020309 | val_loss = 0.022472
# Epoch 037/50 | train_loss = 0.019592 | val_loss = 0.021503
# Epoch 038/50 | train_loss = 0.019375 | val_loss = 0.019650
# Epoch 039/50 | train_loss = 0.018805 | val_loss = 0.019623
# Epoch 040/50 | train_loss = 0.018565 | val_loss = 0.022652
# Epoch 041/50 | train_loss = 0.018537 | val_loss = 0.020391
# Epoch 042/50 | train_loss = 0.017952 | val_loss = 0.019181
# Epoch 043/50 | train_loss = 0.017536 | val_loss = 0.018060
# Epoch 044/50 | train_loss = 0.017301 | val_loss = 0.019663
# Epoch 045/50 | train_loss = 0.017055 | val_loss = 0.019487
# Epoch 046/50 | train_loss = 0.016993 | val_loss = 0.017736
# Epoch 047/50 | train_loss = 0.016685 | val_loss = 0.016994
# Epoch 048/50 | train_loss = 0.016520 | val_loss = 0.017008
# Epoch 049/50 | train_loss = 0.016007 | val_loss = 0.017071
# Epoch 050/50 | train_loss = 0.015835 | val_loss = 0.015980
# → Final val_loss = 0.015980
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 0.0001
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.899990 | val_loss = 0.725025
# Epoch 002/5 | train_loss = 0.617863 | val_loss = 0.535370
# Epoch 003/5 | train_loss = 0.488895 | val_loss = 0.449803
# Epoch 004/5 | train_loss = 0.421353 | val_loss = 0.398664
# Epoch 005/5 | train_loss = 0.375933 | val_loss = 0.360555
# → Final val_loss = 0.360555
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 0.0001
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.904201 | val_loss = 0.723764
# Epoch 002/10 | train_loss = 0.611676 | val_loss = 0.528459
# Epoch 003/10 | train_loss = 0.488274 | val_loss = 0.447985
# Epoch 004/10 | train_loss = 0.421011 | val_loss = 0.396010
# Epoch 005/10 | train_loss = 0.375482 | val_loss = 0.359937
# Epoch 006/10 | train_loss = 0.341917 | val_loss = 0.330591
# Epoch 007/10 | train_loss = 0.315559 | val_loss = 0.307476
# Epoch 008/10 | train_loss = 0.294075 | val_loss = 0.288723
# Epoch 009/10 | train_loss = 0.276118 | val_loss = 0.273253
# Epoch 010/10 | train_loss = 0.260898 | val_loss = 0.259128
# → Final val_loss = 0.259128
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 0.0001
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.899073 | val_loss = 0.720925
# Epoch 002/50 | train_loss = 0.615561 | val_loss = 0.534547
# Epoch 003/50 | train_loss = 0.487511 | val_loss = 0.448207
# Epoch 004/50 | train_loss = 0.416698 | val_loss = 0.392856
# Epoch 005/50 | train_loss = 0.369462 | val_loss = 0.355292
# Epoch 006/50 | train_loss = 0.336024 | val_loss = 0.327269
# Epoch 007/50 | train_loss = 0.310107 | val_loss = 0.304413
# Epoch 008/50 | train_loss = 0.288738 | val_loss = 0.285826
# Epoch 009/50 | train_loss = 0.270999 | val_loss = 0.268842
# Epoch 010/50 | train_loss = 0.255570 | val_loss = 0.254937
# Epoch 011/50 | train_loss = 0.241942 | val_loss = 0.241895
# Epoch 012/50 | train_loss = 0.230313 | val_loss = 0.231151
# Epoch 013/50 | train_loss = 0.219624 | val_loss = 0.220810
# Epoch 014/50 | train_loss = 0.210329 | val_loss = 0.211969
# Epoch 015/50 | train_loss = 0.201678 | val_loss = 0.204192
# Epoch 016/50 | train_loss = 0.193915 | val_loss = 0.197049
# Epoch 017/50 | train_loss = 0.186835 | val_loss = 0.189811
# Epoch 018/50 | train_loss = 0.180140 | val_loss = 0.183744
# Epoch 019/50 | train_loss = 0.174014 | val_loss = 0.177624
# Epoch 020/50 | train_loss = 0.168277 | val_loss = 0.171942
# Epoch 021/50 | train_loss = 0.162756 | val_loss = 0.166601
# Epoch 022/50 | train_loss = 0.157678 | val_loss = 0.161402
# Epoch 023/50 | train_loss = 0.152959 | val_loss = 0.157083
# Epoch 024/50 | train_loss = 0.148376 | val_loss = 0.152300
# Epoch 025/50 | train_loss = 0.144099 | val_loss = 0.147795
# Epoch 026/50 | train_loss = 0.139816 | val_loss = 0.143732
# Epoch 027/50 | train_loss = 0.135992 | val_loss = 0.140123
# Epoch 028/50 | train_loss = 0.132393 | val_loss = 0.136855
# Epoch 029/50 | train_loss = 0.128819 | val_loss = 0.133207
# Epoch 030/50 | train_loss = 0.125500 | val_loss = 0.129509
# Epoch 031/50 | train_loss = 0.122167 | val_loss = 0.126199
# Epoch 032/50 | train_loss = 0.119067 | val_loss = 0.122880
# Epoch 033/50 | train_loss = 0.116039 | val_loss = 0.120262
# Epoch 034/50 | train_loss = 0.113249 | val_loss = 0.117143
# Epoch 035/50 | train_loss = 0.110535 | val_loss = 0.114346
# Epoch 036/50 | train_loss = 0.107727 | val_loss = 0.111915
# Epoch 037/50 | train_loss = 0.105216 | val_loss = 0.109221
# Epoch 038/50 | train_loss = 0.102665 | val_loss = 0.106558
# Epoch 039/50 | train_loss = 0.100242 | val_loss = 0.104211
# Epoch 040/50 | train_loss = 0.097871 | val_loss = 0.101837
# Epoch 041/50 | train_loss = 0.095506 | val_loss = 0.099397
# Epoch 042/50 | train_loss = 0.093332 | val_loss = 0.096763
# Epoch 043/50 | train_loss = 0.091178 | val_loss = 0.094655
# Epoch 044/50 | train_loss = 0.088973 | val_loss = 0.092754
# Epoch 045/50 | train_loss = 0.087138 | val_loss = 0.090841
# Epoch 046/50 | train_loss = 0.085032 | val_loss = 0.088555
# Epoch 047/50 | train_loss = 0.083129 | val_loss = 0.086368
# Epoch 048/50 | train_loss = 0.081260 | val_loss = 0.084445
# Epoch 049/50 | train_loss = 0.079436 | val_loss = 0.082782
# Epoch 050/50 | train_loss = 0.077572 | val_loss = 0.080823
# → Final val_loss = 0.080823
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 1e-05
#    epochs     = 5
# ============================================================
# Epoch 001/5 | train_loss = 0.999110 | val_loss = 0.989359
# Epoch 002/5 | train_loss = 0.986466 | val_loss = 0.973954
# Epoch 003/5 | train_loss = 0.966335 | val_loss = 0.949069
# Epoch 004/5 | train_loss = 0.936435 | val_loss = 0.914601
# Epoch 005/5 | train_loss = 0.897856 | val_loss = 0.872684
# → Final val_loss = 0.872684
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 1e-05
#    epochs     = 10
# ============================================================
# Epoch 001/10 | train_loss = 0.999488 | val_loss = 0.990451
# Epoch 002/10 | train_loss = 0.988391 | val_loss = 0.976607
# Epoch 003/10 | train_loss = 0.969887 | val_loss = 0.952707
# Epoch 004/10 | train_loss = 0.940661 | val_loss = 0.917925
# Epoch 005/10 | train_loss = 0.901623 | val_loss = 0.874002
# Epoch 006/10 | train_loss = 0.855275 | val_loss = 0.826096
# Epoch 007/10 | train_loss = 0.808585 | val_loss = 0.780727
# Epoch 008/10 | train_loss = 0.765853 | val_loss = 0.740769
# Epoch 009/10 | train_loss = 0.728780 | val_loss = 0.706920
# Epoch 010/10 | train_loss = 0.696934 | val_loss = 0.677939
# → Final val_loss = 0.677939
#
# ============================================================
# 🔍 Testing combination:
#    batch_size = 512
#    lr         = 1e-05
#    epochs     = 50
# ============================================================
# Epoch 001/50 | train_loss = 0.998915 | val_loss = 0.990202
# Epoch 002/50 | train_loss = 0.988171 | val_loss = 0.976589
# Epoch 003/50 | train_loss = 0.969993 | val_loss = 0.952029
# Epoch 004/50 | train_loss = 0.939477 | val_loss = 0.914703
# Epoch 005/50 | train_loss = 0.898474 | val_loss = 0.869054
# Epoch 006/50 | train_loss = 0.851588 | val_loss = 0.820401
# Epoch 007/50 | train_loss = 0.804642 | val_loss = 0.774615
# Epoch 008/50 | train_loss = 0.762191 | val_loss = 0.734913
# Epoch 009/50 | train_loss = 0.725749 | val_loss = 0.701498
# Epoch 010/50 | train_loss = 0.694873 | val_loss = 0.673424
# Epoch 011/50 | train_loss = 0.668456 | val_loss = 0.649180
# Epoch 012/50 | train_loss = 0.645306 | val_loss = 0.627931
# Epoch 013/50 | train_loss = 0.624863 | val_loss = 0.609071
# Epoch 014/50 | train_loss = 0.606519 | val_loss = 0.592101
# Epoch 015/50 | train_loss = 0.589803 | val_loss = 0.576580
# Epoch 016/50 | train_loss = 0.574509 | val_loss = 0.562246
# Epoch 017/50 | train_loss = 0.560355 | val_loss = 0.549143
# Epoch 018/50 | train_loss = 0.547197 | val_loss = 0.536902
# Epoch 019/50 | train_loss = 0.534855 | val_loss = 0.525462
# Epoch 020/50 | train_loss = 0.523248 | val_loss = 0.514556
# Epoch 021/50 | train_loss = 0.512331 | val_loss = 0.504438
# Epoch 022/50 | train_loss = 0.501990 | val_loss = 0.494881
# Epoch 023/50 | train_loss = 0.492246 | val_loss = 0.485672
# Epoch 024/50 | train_loss = 0.482921 | val_loss = 0.477150
# Epoch 025/50 | train_loss = 0.474143 | val_loss = 0.468807
# Epoch 026/50 | train_loss = 0.465680 | val_loss = 0.461025
# Epoch 027/50 | train_loss = 0.457646 | val_loss = 0.453556
# Epoch 028/50 | train_loss = 0.450030 | val_loss = 0.446370
# Epoch 029/50 | train_loss = 0.442670 | val_loss = 0.439568
# Epoch 030/50 | train_loss = 0.435739 | val_loss = 0.433022
# Epoch 031/50 | train_loss = 0.429044 | val_loss = 0.426914
# Epoch 032/50 | train_loss = 0.422678 | val_loss = 0.420808
# Epoch 033/50 | train_loss = 0.416623 | val_loss = 0.415226
# Epoch 034/50 | train_loss = 0.410791 | val_loss = 0.409781
# Epoch 035/50 | train_loss = 0.405250 | val_loss = 0.404504
# Epoch 036/50 | train_loss = 0.399860 | val_loss = 0.399504
# Epoch 037/50 | train_loss = 0.394741 | val_loss = 0.394694
# Epoch 038/50 | train_loss = 0.389817 | val_loss = 0.390021
# Epoch 039/50 | train_loss = 0.385030 | val_loss = 0.385627
# Epoch 040/50 | train_loss = 0.380499 | val_loss = 0.381390
# Epoch 041/50 | train_loss = 0.376152 | val_loss = 0.377116
# Epoch 042/50 | train_loss = 0.371752 | val_loss = 0.373070
# Epoch 043/50 | train_loss = 0.367660 | val_loss = 0.369176
# Epoch 044/50 | train_loss = 0.363662 | val_loss = 0.365376
# Epoch 045/50 | train_loss = 0.359738 | val_loss = 0.361722
# Epoch 046/50 | train_loss = 0.355951 | val_loss = 0.358101
# Epoch 047/50 | train_loss = 0.352362 | val_loss = 0.354573
# Epoch 048/50 | train_loss = 0.348722 | val_loss = 0.351122
# Epoch 049/50 | train_loss = 0.345220 | val_loss = 0.347853
# Epoch 050/50 | train_loss = 0.341855 | val_loss = 0.344628
# → Final val_loss = 0.344628
#
# ============================================================
# 🏆 BEST MODEL FOUND
#    batch_size = 128
#    lr         = 0.001
#    epochs     = 50
#    best val_loss = 0.011070
#    Saved as: CNN_BEST.pt
# ============================================================

# %%
# =============================================================================
print('\n⏳ Step 3.3: ESN...')

class ESN(nn.Module):
    def __init__(self,
                 n_features,
                 window,
                 n_reservoir=800,
                 spectral_radius=0.9,
                 sparsity=0.95,
                 leak_rate=1.0,
                 ridge_alpha=1e-6,
                 device="cpu"):
        super().__init__()

        self.n_features = n_features
        self.window = window
        self.n_reservoir = n_reservoir
        self.leak_rate = leak_rate
        self.ridge_alpha = ridge_alpha
        self.device = torch.device(device)

        # Input weights: (n_reservoir, n_features)
        self.W_in = torch.empty(n_reservoir, n_features, device=self.device)
        nn.init.uniform_(self.W_in, -0.5, 0.5)

        # Reservoir weights (sparse)
        W = torch.randn(n_reservoir, n_reservoir, device=self.device)
        mask = (torch.rand_like(W) > sparsity).float()
        W = W * mask

        # Normalize spectral radius
        eigvals = torch.linalg.eigvals(W).abs()
        rho = eigvals.max().real
        W = W * (spectral_radius / rho)

        self.W = W

        # Readout weights (to be learned)
        self.W_out = nn.Parameter(torch.zeros(n_features, n_reservoir))

    @torch.no_grad()
    def fit(self, X, Y, washout=50):
        """
        X: (N, window, n_features)
        Y: (N, n_features)
        """
        X = X.to(self.device)
        Y = Y.to(self.device)

        N = X.shape[0]
        states = []

        for i in range(N):
            x_res = torch.zeros(self.n_reservoir, device=self.device)

            # feed the window through the reservoir
            for t in range(self.window):
                u_t = X[i, t]
                pre = self.W_in @ u_t + self.W @ x_res
                x_res = (1 - self.leak_rate) * x_res + self.leak_rate * torch.tanh(pre)

            states.append(x_res.clone())

        R = torch.stack(states)  # (N, n_reservoir)

        # Ridge regression: W_out = Y R^T (R R^T + αI)^(-1)
        Rt = R.T
        A = Rt @ R + self.ridge_alpha * torch.eye(self.n_reservoir, device=self.device)
        B = Rt @ Y
        self.W_out.data = torch.linalg.solve(A, B).T

    def forward(self, X):
        """
        X: (batch, window, n_features)
        Output: (batch, n_features)
        """
        batch = X.shape[0]
        X = X.to(self.device)

        outputs = []
        for i in range(batch):
            x_res = torch.zeros(self.n_reservoir, device=self.device)

            for t in range(self.window):
                u_t = X[i, t]
                pre = self.W_in @ u_t + self.W @ x_res
                x_res = (1 - self.leak_rate) * x_res + self.leak_rate * torch.tanh(pre)

            y = self.W_out @ x_res
            outputs.append(y)

        return torch.stack(outputs, dim=0)
# Out:
# ⏳ Step 3.3: ESN...

# %%
def esn_train_and_search(Xtr, Ytr, Xvl, Yvl,
                         N_RES=[500, 1000, 1500],
                         SPECT=[0.8, 0.9, 1.0],
                         RIDGE=[1e-4, 1e-6, 1e-8],
                         name="ESN"):
    device = "cuda"

    best_global_loss = float("inf")
    best_params = None
    best_state = None

    # Tutte le combinazioni degli iperparametri ESN
    for n_res, sr, ra in itertools.product(N_RES, SPECT, RIDGE):

        print("\n============================================================")
        print("🔍 Testing ESN combination:")
        print(f"   n_reservoir    = {n_res}")
        print(f"   spectral_radius = {sr}")
        print(f"   ridge_alpha     = {ra}")
        print("============================================================")
        # Ricostruisci un modello ESN nuovo
        model = ESN(n_features=40, window=WINDOW, device="cuda",
                    n_reservoir=n_res, spectral_radius=sr, ridge_alpha=ra).to(device)
        # -------------------------
        # FIT (training ESN)
        # -------------------------
        model.fit(Xtr,Ytr)
        # -------------------------
        # VALIDATION
        # -------------------------
        model.eval()
        criterion = nn.MSELoss()

        with torch.no_grad():
            pred = model(Xvl)
            val_loss = criterion(pred, Yvl).item()

        print(f"→ Validation loss = {val_loss:.6f}")

        # -------------------------
        # BEST MODEL UPDATE
        # -------------------------
        if val_loss < best_global_loss:
            best_global_loss = val_loss
            best_params = (n_res, sr, ra)
            best_state = model.state_dict()
            best_model = model
            print("⭐ New best ESN found!")

    # Ricostruisci il best model e carica i pesi
    #best_model = ESN(n_features=40, window=WINDOW, device="cuda",
    #                 n_reservoir=best_params[0],
    #                 spectral_radius=best_params[1],
    #                 ridge_alpha=best_params[2]).to(device)
    #best_model.load_state_dict(best_state)

    print("\n============================================================")
    print("🏆 BEST ESN FOUND")
    print(f"   n_reservoir    = {best_params[0]}")
    print(f"   spectral_radius = {best_params[1]}")
    print(f"   ridge_alpha     = {best_params[2]}")
    print(f"   best val_loss   = {best_global_loss:.6f}")
    print("============================================================")

    return best_model, best_params, best_global_loss


Xtr = torch.tensor(X96_win_tr, dtype=torch.float32).to("cuda")
Ytr = torch.tensor(Y96_tr, dtype=torch.float32).to("cuda")
Xvl = torch.tensor(X96_win_vl, dtype=torch.float32).to("cuda")
Yvl = torch.tensor(Y96_vl, dtype=torch.float32).to("cuda")
print('\n🏗️  Training ESN...')
esn, esn_params, esn_loss = esn_train_and_search(
    Xtr, Ytr,
    Xvl, Yvl,
    N_RES=[1000,1500,2000],
    SPECT=[0.8,0.9,1.0],
    RIDGE=[1e-5,1e-6,1e-7],
    name="ESN"
)
# Out:
# 🏗️  Training ESN...
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1000
#    spectral_radius = 0.8
#    ridge_alpha     = 1e-05
# ============================================================
# → Validation loss = 0.041832
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1000
#    spectral_radius = 0.8
#    ridge_alpha     = 1e-06
# ============================================================
# → Validation loss = 0.042011
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1000
#    spectral_radius = 0.8
#    ridge_alpha     = 1e-07
# ============================================================
# → Validation loss = 0.041568
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1000
#    spectral_radius = 0.9
#    ridge_alpha     = 1e-05
# ============================================================
# → Validation loss = 0.040563
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1000
#    spectral_radius = 0.9
#    ridge_alpha     = 1e-06
# ============================================================
# → Validation loss = 0.041285
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1000
#    spectral_radius = 0.9
#    ridge_alpha     = 1e-07
# ============================================================
# → Validation loss = 0.040927
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1000
#    spectral_radius = 1.0
#    ridge_alpha     = 1e-05
# ============================================================
# → Validation loss = 0.040197
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1000
#    spectral_radius = 1.0
#    ridge_alpha     = 1e-06
# ============================================================
# → Validation loss = 0.040466
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1000
#    spectral_radius = 1.0
#    ridge_alpha     = 1e-07
# ============================================================
# → Validation loss = 0.040305
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1500
#    spectral_radius = 0.8
#    ridge_alpha     = 1e-05
# ============================================================
# → Validation loss = 0.035428
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1500
#    spectral_radius = 0.8
#    ridge_alpha     = 1e-06
# ============================================================
# → Validation loss = 0.035279
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1500
#    spectral_radius = 0.8
#    ridge_alpha     = 1e-07
# ============================================================
# → Validation loss = 0.035499
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1500
#    spectral_radius = 0.9
#    ridge_alpha     = 1e-05
# ============================================================
# → Validation loss = 0.034260
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1500
#    spectral_radius = 0.9
#    ridge_alpha     = 1e-06
# ============================================================
# → Validation loss = 0.033968
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1500
#    spectral_radius = 0.9
#    ridge_alpha     = 1e-07
# ============================================================
# → Validation loss = 0.034343
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1500
#    spectral_radius = 1.0
#    ridge_alpha     = 1e-05
# ============================================================
# → Validation loss = 0.033387
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1500
#    spectral_radius = 1.0
#    ridge_alpha     = 1e-06
# ============================================================
# → Validation loss = 0.033597
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 1500
#    spectral_radius = 1.0
#    ridge_alpha     = 1e-07
# ============================================================
# → Validation loss = 0.033504
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 2000
#    spectral_radius = 0.8
#    ridge_alpha     = 1e-05
# ============================================================
# → Validation loss = 0.031607
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 2000
#    spectral_radius = 0.8
#    ridge_alpha     = 1e-06
# ============================================================
# → Validation loss = 0.031425
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 2000
#    spectral_radius = 0.8
#    ridge_alpha     = 1e-07
# ============================================================
# → Validation loss = 0.031459
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 2000
#    spectral_radius = 0.9
#    ridge_alpha     = 1e-05
# ============================================================
# → Validation loss = 0.030288
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 2000
#    spectral_radius = 0.9
#    ridge_alpha     = 1e-06
# ============================================================
# → Validation loss = 0.029943
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 2000
#    spectral_radius = 0.9
#    ridge_alpha     = 1e-07
# ============================================================
# → Validation loss = 0.030270
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 2000
#    spectral_radius = 1.0
#    ridge_alpha     = 1e-05
# ============================================================
# → Validation loss = 0.029361
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 2000
#    spectral_radius = 1.0
#    ridge_alpha     = 1e-06
# ============================================================
# → Validation loss = 0.029103
# ⭐ New best ESN found!
#
# ============================================================
# 🔍 Testing ESN combination:
#    n_reservoir    = 2000
#    spectral_radius = 1.0
#    ridge_alpha     = 1e-07
# ============================================================
# → Validation loss = 0.029404
#
# ============================================================
# 🏆 BEST ESN FOUND
#    n_reservoir    = 2000
#    spectral_radius = 1.0
#    ridge_alpha     = 1e-06
#    best val_loss   = 0.029103
# ============================================================

# %% [markdown]
# ## FORECASTING E METRICHE

# %%
# =============================================================================
# 🔁 STEP 4: AUTOREGRESSIVE FORECASTING AND TIME-SERIES EVALUATION
# =============================================================================
print('\n⏳ Step 4: Initializing accelerated autoregressive evaluation engine...')
LEAD = 200   # Maximum forecast lead time to evaluate (steps)

def autoregressive_forecast(model, X_init, n_steps, device="cpu"):
    """
    Autoregressive multi-step forecasting in PyTorch.
    """
    # Convert initial window to tensor ON THE CORRECT DEVICE
    window_buf = torch.tensor(X_init, dtype=torch.float32, device=device)

    preds = np.zeros((n_steps, X_init.shape[-1]), dtype=np.float32)

    for step in range(n_steps):

        # Add batch dimension
        inp = window_buf.unsqueeze(0)  # (1, window, features)

        # Forward pass
        with torch.no_grad():
            pred_tensor = model(inp)  # stays on GPU if model is on GPU

        # Convert to numpy
        pred = pred_tensor.squeeze(0).cpu().numpy()
        preds[step] = pred

        # Slide window
        pred_t = pred_tensor.squeeze(0)  # still on GPU
        window_buf = torch.cat([window_buf[1:], pred_t.unsqueeze(0)], dim=0)

    return preds




def rmse_vs_lead(model, X_win_te, Y_te, lead, device=device):
    """
    Compute RMSE, MAE, and BIAS vs lead time for a PyTorch model.
    """
    n_test = X_win_te.shape[0]
    indices = np.arange(0, n_test - lead, 50)

    rmse = np.zeros(lead)
    mae  = np.zeros(lead)
    bias = np.zeros(lead)

    for idx in indices:
        true_future = Y_te[idx : idx + lead]
        pred_future = autoregressive_forecast(model, X_win_te[idx], lead, device=device)

        diff = true_future - pred_future

        rmse += np.sqrt(np.mean(diff**2, axis=1))
        mae  += np.mean(np.abs(diff), axis=1)
        bias += np.mean(diff, axis=1)

    rmse /= len(indices)
    mae  /= len(indices)
    bias /= len(indices)

    return rmse, mae, bias
   


def phys_rmse_emulator(rhs_func, X_win_te, Y_te, lead, mu, sig, dt):
    """
    Compute RMSE, MAE, and BIAS for the true physics emulator (RK4).
    """
    def rk4_step(s, dt):
        k1 = rhs_func(s)
        k2 = rhs_func(s + 0.5 * dt * k1)
        k3 = rhs_func(s + 0.5 * dt * k2)
        k4 = rhs_func(s + dt * k3)
        return s + (dt / 6.0) * (k1 + 2*k2 + 2*k3 + k4)

    n_test = X_win_te.shape[0]
    indices = np.arange(0, n_test - lead, 50)

    rmse = np.zeros(lead)
    mae  = np.zeros(lead)
    bias = np.zeros(lead)

    for idx in indices:
        s = X_win_te[idx, -1] * sig + mu
        true_future = Y_te[idx : idx + lead]

        preds = np.zeros_like(true_future)
        for step in range(lead):
            s = rk4_step(s, dt)
            preds[step] = (s - mu) / sig

        diff = true_future - preds

        rmse += np.sqrt(np.mean(diff**2, axis=1))
        mae  += np.mean(np.abs(diff), axis=1)
        bias += np.mean(diff, axis=1)

    rmse /= len(indices)
    mae  /= len(indices)
    bias /= len(indices)

    return rmse, mae, bias


# =============================================================================
# 🌪️ DYNAMICAL SYSTEM RHS EQUATION REPOSITORIES
# =============================================================================
def l96_rhs(s, F=8.0):
    return (np.roll(s, -1) - np.roll(s, 2)) * np.roll(s, 1) - s + F

mlp = MLP(n_features=L96_N, window=WINDOW)
cnn = CNN(n_features=L96_N, window=WINDOW)

mlp.load_state_dict(torch.load("MLP_BEST.pt"))
cnn.load_state_dict(torch.load("CNN_BEST.pt"))
mlp.to(device).eval()
cnn.to(device).eval()
esn.to(device)


print('  🌐 Processing Lorenz 96 Multi-step Metrics...')
t96       = np.arange(1, LEAD + 1) * 0.05 
rms_phy96 = phys_rmse_emulator(l96_rhs, X96_win_te, Y96_te, LEAD, mu96, sig96, dt=0.05)
print("phys_rmse_emulator:ok")
rms_mlp96 = rmse_vs_lead(mlp, X96_win_te, Y96_te, LEAD)
print("mlp:ok")
rms_cnn96 = rmse_vs_lead(cnn, X96_win_te, Y96_te, LEAD)
print("cnn:ok")
rms_esn96 = rmse_vs_lead(esn, X96_win_te, Y96_te, LEAD)
print("esn:ok")

# Calculate Climatological Skill Threshold limits
clim96 = np.std(Y96_te) * np.sqrt(2)

def pred_horizon(rmse, clim):
    idx = np.where(rmse >= clim)[0]
    return idx[0] if len(idx) > 0 else len(rmse)

# Calculate physical predictability landmarks
ph_phy96 = pred_horizon(rms_phy96[0], clim96)
ph_mlp96 = pred_horizon(rms_mlp96[0], clim96)
ph_cnn96 = pred_horizon(rms_cnn96[0], clim96)
ph_esn96 = pred_horizon(rms_esn96[0], clim96)

print("\n🎯 Predictability Horizons (Lead Steps until Skill Saturation):", ph_phy96)
print(f"   • L96 Domain -> True Physics: {ph_phy96:3d} steps | MLP Emulator: {ph_mlp96:3d} steps")
print(f"   • L96 Domain -> True Physics: {ph_phy96:3d} steps | CNN Emulator: {ph_cnn96:3d} steps")
print(f"   • L96 Domain -> True Physics: {ph_phy96:3d} steps | ESN Emulator: {ph_esn96:3d} steps")

# =============================================================================
# 📈 VISUALIZATION SUITE ENGINE
# =============================================================================
fig, axes = plt.subplots(1, 3, figsize=(14, 4.5))

# Plot Lorenz 96 [0]
axes[0].plot(t96, rms_phy96[0], color='black', lw=1.5, label='Physical RK4 Reference')
axes[0].plot(t96, rms_mlp96[0], color='royalblue', linestyle='--', label='MLP Baseline')
axes[0].plot(t96, rms_cnn96[0], color='crimson', linestyle='-.', label='CNN Spatial Filter')
axes[0].plot(t96, rms_esn96[0], color='green', linestyle='-.', label='esn')
axes[0].axhline(clim96, color='gray', linestyle=':', label='Climatology Line')
axes[0].set_ylim(bottom=0,top=2)
axes[0].set_xlabel('Lead Time (Mean Time Units - MTU)')
axes[0].set_ylabel('Root Mean Squared Error (RMSE)')
axes[0].set_title('Root Mean Square Error Growth Curves')
axes[0].grid(True, linestyle=':', alpha=0.6)
axes[0].legend(framealpha=0.9)

# Plot Lorenz 96 [1]
axes[1].plot(t96, rms_phy96[1], color='black', lw=1.5, label='Physical RK4 Reference')
axes[1].plot(t96, rms_mlp96[1], color='royalblue', linestyle='--', label='MLP Baseline')
axes[1].plot(t96, rms_cnn96[1], color='crimson', linestyle='-.', label='CNN Spatial Filter')
axes[1].plot(t96, rms_esn96[1], color='green', linestyle='-.', label='ESN')
axes[1].set_ylim(bottom=0,top=2)
#axes[1].axhline(clim96, color='gray', linestyle=':', label='Climatology Line')
axes[1].set_xlabel('Lead Time (Mean Time Units - MTU)')
axes[1].set_ylabel('Mean Absolute Error (MAE)')
axes[1].set_title('Mean Absolute Error Growth Curves')
axes[1].grid(True, linestyle=':', alpha=0.6)
axes[1].legend(framealpha=0.9)

# Plot Lorenz 96 [2]
axes[2].plot(t96, rms_phy96[2], color='black', lw=1.5, label='Physical RK4 Reference')
axes[2].plot(t96, rms_mlp96[2], color='royalblue', linestyle='--', label='MLP Baseline')
axes[2].plot(t96, rms_cnn96[2], color='crimson', linestyle='-.', label='CNN Spatial Filter')
axes[2].plot(t96, rms_esn96[2], color='green', linestyle='-.', label='ESN')
axes[2].set_ylim(bottom=-0.15,top=0.15)
#axes[2].axhline(clim96, color='gray', linestyle=':', label='Climatology Line')
axes[2].set_xlabel('Lead Time (Mean Time Units - MTU)')
axes[2].set_ylabel('Bias')
axes[2].set_title('Bias Growth Curves')
axes[2].grid(True, linestyle=':', alpha=0.6)
axes[2].legend(framealpha=0.9)


plt.tight_layout()
plt.savefig('step4_rmse.png', dpi=150)
plt.show()
plt.close()

print('\n✓ [OK] Step 4 complete. Multi-model error tracking plot saved as: step4_rmse.png')
# Out:
# ⏳ Step 4: Initializing accelerated autoregressive evaluation engine...
#   🌐 Processing Lorenz 96 Multi-step Metrics...
# phys_rmse_emulator:ok
# mlp:ok
# cnn:ok
# esn:ok
#
# 🎯 Predictability Horizons (Lead Steps until Skill Saturation): 200
#    • L96 Domain -> True Physics: 200 steps | MLP Emulator:  23 steps
#    • L96 Domain -> True Physics: 200 steps | CNN Emulator:   7 steps
#    • L96 Domain -> True Physics: 200 steps | ESN Emulator:  23 steps
# ✓ [OK] Step 4 complete. Multi-model error tracking plot saved as: step4_rmse.png

# %%
# =============================================================================
# 🌪️ STEP 5: ACCELERATED MAXIMUM LYAPUNOV EXPONENT (MLE) ANALYSIS
# =============================================================================
print('\n⏳ Step 5: Computing chaotic attractor Lyapunov divergence rates...')

EPS = 1e-6   # Perturbation distance amplitude (bounded within linear regime)


def compute_physical_mle(rhs_func, x0, n_steps, dt, eps=EPS):
    """
    Generalized high-fidelity Benettin algorithm for physical RK4 vector fields.
    """
    def rk4_step(s, dt):
        k1 = rhs_func(s)
        k2 = rhs_func(s + 0.5 * dt * k1)
        k3 = rhs_func(s + 0.5 * dt * k2)
        k4 = rhs_func(s + dt * k3)
        return s + (dt / 6.0) * (k1 + 2.0 * k2 + 2.0 * k3 + k4)

    # Initialize a random hypersphere surface perturbation vector
    delta = np.random.randn(len(x0))
    delta = (delta / np.linalg.norm(delta)) * eps
    
    s = x0.copy()
    s_per = s + delta
    lyap_sum = 0.0

    for _ in range(n_steps):
        s = rk4_step(s, dt)
        s_per = rk4_step(s_per, dt)
        
        new_delta = s_per - s
        growth = np.linalg.norm(new_delta)
        
        lyap_sum += np.log(growth / eps)
        s_per = s + (new_delta / growth) * eps     # Continuous rescaling back to original orbit radius

    return lyap_sum / (n_steps * dt)   # Outputs invariant rate scaled exactly to 1/MTU


def compute_ml_mle(model, x0_norm, n_steps, dt_sampling, eps=1e-6):
    """
    ML-based Lyapunov exponent estimator using autoregressive divergence tracking.
    PyTorch version with correct device handling.
    """

    # Detect device from model parameters
    device = next(model.parameters()).device

    # Convert initial window to tensor ON THE SAME DEVICE AS THE MODEL
    buf = torch.tensor(x0_norm, dtype=torch.float32, device=device)

    # Create normalized perturbation vector
    pert = np.random.randn(x0_norm.shape[-1])
    pert = (pert / np.linalg.norm(pert)) * eps

    # Apply perturbation only to the last snapshot
    pert_mask = np.zeros_like(x0_norm)
    pert_mask[-1] = pert

    buf_per = torch.tensor(x0_norm + pert_mask, dtype=torch.float32, device=device)

    lyap_sum = 0.0

    for _ in range(n_steps):

        # Add batch dimension
        inp     = buf.unsqueeze(0)
        inp_per = buf_per.unsqueeze(0)

        # Forward pass
        with torch.no_grad():
            pred     = model(inp)      # stays on GPU
            pred_per = model(inp_per)  # stays on GPU

        # Divergence vector
        delta = pred_per[0] - pred[0]
        growth = torch.norm(delta).item()

        if growth < 1e-15:
            break

        lyap_sum += np.log(growth / eps)

        # Slide window
        buf = torch.cat([buf[1:], pred[0].unsqueeze(0)], dim=0)

        # Renormalize perturbation
        next_pert_state = pred[0] + (delta / growth) * eps
        buf_per = torch.cat([buf_per[1:], next_pert_state.unsqueeze(0)], dim=0)

    return lyap_sum / (n_steps * dt_sampling)



# =============================================================================
# 🚀 SYSTEM MODEL METRIC COMPILATION RUNS
# =============================================================================

# Define system vector fields (matching steps 1 and 4 formulations)
l96_rhs = lambda s, F=8.0: (np.roll(s, -1) - np.roll(s, 2)) * np.roll(s, 1) - s + F

# 1. Physical System Base Exponents
print("  🌊 Running physical trajectory integration runs...")
# FIX: Extract the complete spatial vector coordinates at slice index 500
ic96_phys = X96_test_n[500, :] * sig96 + mu96

mle_phy96 = compute_physical_mle(l96_rhs, ic96_phys, n_steps=5000, dt=0.05)

# 2. Neural Network Emulator Maps Exponents 
print("  🧠 Running neural network map evaluations...")
ic_win96 = X96_test_n[0:WINDOW]

mle_mlp96 = compute_ml_mle(mlp, ic_win96, n_steps=3000, dt_sampling=0.05)
mle_cnn96 = compute_ml_mle(cnn, ic_win96, n_steps=3000, dt_sampling=0.05)
mle_esn96 = compute_ml_mle(esn, ic_win96, n_steps=3000, dt_sampling=0.05)


# =============================================================================
# 📋 FINAL ATTRACTOR GEOMETRY VERIFICATION REPORT
# =============================================================================
print("\n📋 Attractor Geometric Chaos Verification Matrix (Units: 1/MTU):")
print("======================================================================")
print(f"🌐 Lorenz 96 [True Literature λ ≈ 1.680]")
print(f"   ├── True Physics Integrator : {mle_phy96:0.4f}")
print(f"   ├── MLP Baseline Emulator   : {mle_mlp96:0.4f}")
print(f"   └── CNN Spatial Emulator    : {mle_cnn96:0.4f}")
print(f"   └── ESN Emulator    : {mle_esn96:0.4f}")
print("======================================================================")
print("✓ [OK] Step 5 complete. Chaos metrics compiled and matched to reference domains.")
# Out:
# ⏳ Step 5: Computing chaotic attractor Lyapunov divergence rates...
#   🌊 Running physical trajectory integration runs...
#   🧠 Running neural network map evaluations...
#
# 📋 Attractor Geometric Chaos Verification Matrix (Units: 1/MTU):
# ======================================================================
# 🌐 Lorenz 96 [True Literature λ ≈ 1.680]
#    ├── True Physics Integrator : 1.6713
#    ├── MLP Baseline Emulator   : 14.3646
#    └── CNN Spatial Emulator    : 0.0000
#    └── ESN Emulator    : 5.3019
# ======================================================================
# ✓ [OK] Step 5 complete. Chaos metrics compiled and matched to reference domains.

# %%
fig = plt.figure(figsize=(15, 4), constrained_layout=True)

# -----------------------------
# 1) Hovmöller fisico
# -----------------------------
ax1 = fig.add_subplot(141)

t_end_hov = 200
hov1 = ax1.contourf(
    np.arange(1, L96_N + 1),
    t96[:t_end_hov],
    X96_test_n[WINDOW:t_end_hov+WINDOW, :],
    levels=30, cmap='RdBu_r', extend='both'
)

#cbar1 = plt.colorbar(hov1, ax=ax1, pad=0.02)
#cbar1.set_label('State Intensity Value', fontsize=9)
#cbar1.ax.tick_params(labelsize=8)

ax1.set_xlabel('Spatial Grid Index ($x_1 \dots x_{40}$)', fontsize=10)
ax1.set_ylabel('Time (MTU)', fontsize=10)
ax1.set_title('L96 Physical Hovmöller Diagram', fontsize=11)


# -----------------------------
# 2) Hovmöller MLP
# -----------------------------
X96_mlp= autoregressive_forecast(mlp, X96_test_n[0:WINDOW,:], t_end_hov, device="cuda")
ax2 = fig.add_subplot(142)

hov2 = ax2.contourf(
    np.arange(1, L96_N + 1),
    t96[:t_end_hov],
    X96_mlp[:t_end_hov, :],
    levels=30, cmap='RdBu_r', extend='both'
)

#cbar2 = plt.colorbar(hov2, ax=ax2, pad=0.02)
#cbar2.set_label('State Intensity Value', fontsize=9)
#cbar2.ax.tick_params(labelsize=8)

ax2.set_xlabel('Spatial Grid Index ($x_1 \dots x_{40}$)', fontsize=10)
ax2.set_title('MLP Hovmöller Diagram', fontsize=11)

# -----------------------------
# 2) Hovmöller CNN
# -----------------------------
X96_cnn= autoregressive_forecast(cnn, X96_test_n[0:WINDOW,:], t_end_hov, device="cuda")
ax3 = fig.add_subplot(143)

hov3 = ax3.contourf(
    np.arange(1, L96_N + 1),
    t96[:t_end_hov],
    X96_cnn[:t_end_hov, :],
    levels=30, cmap='RdBu_r', extend='both'
)

#cbar3 = plt.colorbar(hov3, ax=ax3, pad=0.02)
#cbar3.set_label('State Intensity Value', fontsize=9)
#cbar3.ax.tick_params(labelsize=8)

ax3.set_xlabel('Spatial Grid Index ($x_1 \dots x_{40}$)', fontsize=10)
ax3.set_title('CNN Hovmöller Diagram', fontsize=11)


# -----------------------------
# 2) Hovmöller ESN
# -----------------------------
X96_esn= autoregressive_forecast(esn, X96_test_n[0:WINDOW,:], t_end_hov, device="cuda")
ax4 = fig.add_subplot(144)

hov4 = ax4.contourf(
    np.arange(1, L96_N + 1),
    t96[:t_end_hov],
    X96_esn[:t_end_hov, :],
    levels=30, cmap='RdBu_r', extend='both'
)

#cbar4 = plt.colorbar(hov4, ax=ax4, pad=0.02)
#cbar4.set_label('State Intensity Value', fontsize=9)
#cbar4.ax.tick_params(labelsize=8)

ax4.set_xlabel('Spatial Grid Index ($x_1 \dots x_{40}$)', fontsize=10)
ax4.set_title('ESN Hovmöller Diagram', fontsize=11)

cbar4 = fig.colorbar(hov4, ax=[ax1, ax2, ax3, ax4], location='right')
cbar4.set_label('State Intensity Value', fontsize=9)



plt.savefig("hovmoller_comparison.png", dpi=150)
plt.show()
plt.close()

# %%
plt.figure(figsize=(8,5))

# Flatten: tutte le variabili, tutti i tempi
phys_data = X96_test_n.reshape(-1)
mlp_data  = X96_mlp.reshape(-1)
cnn_data = X96_cnn.reshape(-1)
esn_data = X96_esn.reshape(-1)

plt.hist(phys_data, bins=60, density=True, alpha=0.6,
         color='black', label='Physical System')

plt.hist(mlp_data, bins=60, density=True, alpha=0.6,
         color='royalblue', label='MLP Emulator')

plt.hist(cnn_data, bins=60, density=True, alpha=0.6,
         color='red', label='CNN Emulator')

plt.hist(esn_data, bins=60, density=True, alpha=0.6,
         color='green', label='ESN Emulator')

plt.xlabel("State value x", fontsize=12)
plt.ylabel("Probability density", fontsize=12)
plt.title("Lorenz 96 – Global Probability Distribution\nPhysical vs MLP Emulator", fontsize=13)
plt.legend()
plt.grid(True, linestyle=':', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))

# Flatten: tutte le variabili, tutti i tempi
phys_data = X96_test_n[:,20].reshape(-1)
mlp_data  = X96_mlp[:,20].reshape(-1)
cnn_data = X96_cnn[:,20].reshape(-1)
esn_data = X96_esn.reshape(-1)

plt.hist(phys_data, bins=60, density=True, alpha=0.6,
         color='steelblue', label='Physical System')

plt.hist(mlp_data, bins=60, density=True, alpha=0.6,
         color='darkorange', label='MLP Emulator')

plt.hist(cnn_data, bins=60, density=True, alpha=0.6,
         color='seagreen', label='CNN Emulator')

plt.hist(esn_data, bins=60, density=True, alpha=0.6,
         color='crimson', label='ESN Emulator')

plt.xlabel("State value x", fontsize=12)
plt.ylabel("Probability density", fontsize=12)
plt.title("Probability Distribution of $x_{20}$", fontsize=13)
plt.legend()
plt.grid(True, linestyle=':', alpha=0.5)

plt.tight_layout()
plt.savefig("Probability_Distribution.png", dpi=150)
plt.show()

# %%
# -----------------------------------------------------------------------------
# ── Panel: L96 Grid Coordinate Points
# -----------------------------------------------------------------------------
t_plot_lim_96 = 200  # Captures first 20 MTU at Delta t = 0.05

plt.plot(t96[:t_plot_lim_96], Y96_te[:t_plot_lim_96,20],
        color = "steelblue", lw=0.9, 
        label=f'Grid Point $x_{{20}}')

plt.plot(t96[:t_plot_lim_96], X96_mlp[:t_plot_lim_96,20],
        color = "darkorange", lw=0.9, 
        label=f'Mlp')

plt.plot(t96[:t_plot_lim_96], X96_cnn[:t_plot_lim_96,20],
        color = "seagreen", lw=0.9, 
        label=f'Cnn')

plt.plot(t96[:t_plot_lim_96], X96_esn[:t_plot_lim_96,20],
        color = "crimson", lw=0.9, 
        label=f'Esn')
#X96_test_n[:,20].reshape(-1)
#mlp_data  = X96_mlp[:,20].reshape(-1)
#cnn_data = X96_cnn[:,20].reshape(-1)
#esn_data = X96_esn.reshape(-1)

        
# CRITICAL FIX: Moved configuration attributes outside the plotting loop
plt.xlabel('Time (MTU)', fontsize=10)
plt.ylabel('State Magnitude', fontsize=10)
plt.title('Evolution of a single grid-point', fontsize=11)
plt.legend(loc='lower left', fontsize=8, ncol=2, framealpha=0.9)
plt.grid(True, linestyle='--', alpha=0.5)
plt.savefig("evolution.png", dpi=150)
